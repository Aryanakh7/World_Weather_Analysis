# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 611

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | guerrero negro
# Processing Record 2 of Set 1 | south yuba city
# Processing Record 3 of Set 1 | tasiilaq
# Processing Record 4 of Set 1 | tuktoyaktuk
# Processing Record 5 of Set 1 | esperance
# Processing Record 6 of Set 1 | kapaa
# Processing Record 7 of Set 1 | bethel
# Processing Record 8 of Set 1 | east london
# Processing Record 9 of Set 1 | busselton
# Processing Record 10 of Set 1 | yellowknife
# Processing Record 11 of Set 1 | punta arenas
# Processing Record 12 of Set 1 | talnakh
# Processing Record 13 of Set 1 | neuquen
# Processing Record 14 of Set 1 | rikitea
# Processing Record 15 of Set 1 | arraial do cabo
# Processing Record 16 of Set 1 | surt
# Processing Record 17 of Set 1 | ponta delgada
# Processing Record 18 of Set 1 | clyde river
# Processing Record 19 of Set 1 | jamestown
# Processing Record 20 of Set 1 | hermanus
# Processing Record 21 of Set 1 | panzhihua
# Processing Record 22 of Set 1 | casa nova
# Processing Record 23 of Set 1 | hasaki
# Processing Record 24 of Set 1 | provideniya
# Processing Record 25 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 26 of Set 1 | naryan-mar
# Processing Record 27 of Set 1 | ofaqim
# Processing Record 28 of Set 1 | dovolnoye
# Processing Record 29 of Set 1 | omboue
# Processing Record 30 of Set 1 | severo-kurilsk
# Processing Record 31 of Set 1 | darhan
# Processing Record 32 of Set 1 | bluff
# Processing Record 33 of Set 1 | san patricio
# Processing Record 34 of Set 1 | cape town
# Processing Record 35 of Set 1 | maniitsoq
# Processing Record 36 of Set 1 | mattru
# Processing Record 37 of Set 1 | mar del plata
# Processing Record 38 of Set 1 | port elizabeth
# Processing Record 39 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 40 of Set 1 | padang
# Processing Record 41 of Set 1 | tilichiki
# Processing Record 42 of Set 1 | qaanaaq
# Processing Record 43 of Set 1 | jurbarkas
# Processing Record 44 of Set 1 | baykit
# Processing Record 45 of Set 1 | geraldton
# Processing Record 46 of Set 1 | tabukiniberu
# City not found. Skipping...
# Processing Record 47 of Set 1 | butaritari
# Processing Record 48 of Set 1 | mataura
# Processing Record 49 of Set 1 | vila velha
# Processing Record 50 of Set 1 | airai
# Processing Record 1 of Set 2 | sao filipe
# Processing Record 2 of Set 2 | half moon bay
# Processing Record 3 of Set 2 | grand-santi
# Processing Record 4 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 5 of Set 2 | nome
# Processing Record 6 of Set 2 | hobart
# Processing Record 7 of Set 2 | puerto ayora
# Processing Record 8 of Set 2 | san quintin
# Processing Record 9 of Set 2 | khatanga
# Processing Record 10 of Set 2 | conde
# Processing Record 11 of Set 2 | shiraz
# Processing Record 12 of Set 2 | udachnyy
# Processing Record 13 of Set 2 | bredasdorp
# Processing Record 14 of Set 2 | port lincoln
# Processing Record 15 of Set 2 | matara
# Processing Record 16 of Set 2 | rawson
# Processing Record 17 of Set 2 | mocambique
# City not found. Skipping...
# Processing Record 18 of Set 2 | thompson
# Processing Record 19 of Set 2 | dunedin
# Processing Record 20 of Set 2 | bathsheba
# Processing Record 21 of Set 2 | pitimbu
# Processing Record 22 of Set 2 | draper
# Processing Record 23 of Set 2 | benguela
# Processing Record 24 of Set 2 | bambous virieux
# Processing Record 25 of Set 2 | chicama
# Processing Record 26 of Set 2 | narasannapeta
# Processing Record 27 of Set 2 | buenavista
# Processing Record 28 of Set 2 | rodino
# Processing Record 29 of Set 2 | vaini
# Processing Record 30 of Set 2 | kodiak
# Processing Record 31 of Set 2 | albany
# Processing Record 32 of Set 2 | saint-philippe
# Processing Record 33 of Set 2 | carutapera
# Processing Record 34 of Set 2 | chokurdakh
# Processing Record 35 of Set 2 | opuwo
# Processing Record 36 of Set 2 | tahe
# Processing Record 37 of Set 2 | luderitz
# Processing Record 38 of Set 2 | ushuaia
# Processing Record 39 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 40 of Set 2 | avarua
# Processing Record 41 of Set 2 | salalah
# Processing Record 42 of Set 2 | nikolskoye
# Processing Record 43 of Set 2 | novobessergenevka
# Processing Record 44 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 45 of Set 2 | lorengau
# Processing Record 46 of Set 2 | atuona
# Processing Record 47 of Set 2 | pingliang
# Processing Record 48 of Set 2 | moshi
# Processing Record 49 of Set 2 | lebu
# Processing Record 50 of Set 2 | simpang
# Processing Record 1 of Set 3 | kavaratti
# Processing Record 2 of Set 3 | pevek
# Processing Record 3 of Set 3 | barrow
# Processing Record 4 of Set 3 | hilo
# Processing Record 5 of Set 3 | cherskiy
# Processing Record 6 of Set 3 | new norfolk
# Processing Record 7 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 8 of Set 3 | sao jose da coroa grande
# Processing Record 9 of Set 3 | pindobacu
# Processing Record 10 of Set 3 | mandera
# Processing Record 11 of Set 3 | tiksi
# Processing Record 12 of Set 3 | carnarvon
# Processing Record 13 of Set 3 | oyem
# Processing Record 14 of Set 3 | asau
# Processing Record 15 of Set 3 | fairbanks
# Processing Record 16 of Set 3 | hami
# Processing Record 17 of Set 3 | barreirinha
# Processing Record 18 of Set 3 | urdzhar
# City not found. Skipping...
# Processing Record 19 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 20 of Set 3 | tubruq
# City not found. Skipping...
# Processing Record 21 of Set 3 | meulaboh
# Processing Record 22 of Set 3 | yar-sale
# Processing Record 23 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 24 of Set 3 | nurota
# Processing Record 25 of Set 3 | saint-prosper
# Processing Record 26 of Set 3 | dikson
# Processing Record 27 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 28 of Set 3 | bodden town
# Processing Record 29 of Set 3 | georgetown
# Processing Record 30 of Set 3 | nemuro
# Processing Record 31 of Set 3 | marmora
# Processing Record 32 of Set 3 | lagoa
# Processing Record 33 of Set 3 | sao paulo de olivenca
# Processing Record 34 of Set 3 | ahipara
# Processing Record 35 of Set 3 | ponta do sol
# Processing Record 36 of Set 3 | kenscoff
# Processing Record 37 of Set 3 | san nicolas
# Processing Record 38 of Set 3 | banepa
# Processing Record 39 of Set 3 | port pirie
# Processing Record 40 of Set 3 | codrington
# Processing Record 41 of Set 3 | tiarei
# Processing Record 42 of Set 3 | xining
# Processing Record 43 of Set 3 | havelock
# Processing Record 44 of Set 3 | shimanovsk
# Processing Record 45 of Set 3 | twin falls
# Processing Record 46 of Set 3 | tsienyane
# City not found. Skipping...
# Processing Record 47 of Set 3 | olafsvik
# Processing Record 48 of Set 3 | mahebourg
# Processing Record 49 of Set 3 | grindavik
# Processing Record 50 of Set 3 | bull savanna
# Processing Record 1 of Set 4 | kawalu
# Processing Record 2 of Set 4 | xinpu
# Processing Record 3 of Set 4 | mackay
# Processing Record 4 of Set 4 | dorado
# Processing Record 5 of Set 4 | adrar
# Processing Record 6 of Set 4 | longyearbyen
# Processing Record 7 of Set 4 | faya
# Processing Record 8 of Set 4 | monatele
# City not found. Skipping...
# Processing Record 9 of Set 4 | maceio
# Processing Record 10 of Set 4 | karaton
# Processing Record 11 of Set 4 | mwinilunga
# Processing Record 12 of Set 4 | kalemie
# Processing Record 13 of Set 4 | utiroa
# City not found. Skipping...
# Processing Record 14 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 15 of Set 4 | karratha
# Processing Record 16 of Set 4 | peruibe
# Processing Record 17 of Set 4 | doha
# Processing Record 18 of Set 4 | komsomolskiy
# Processing Record 19 of Set 4 | nabire
# Processing Record 20 of Set 4 | oboyan
# Processing Record 21 of Set 4 | narrabri
# Processing Record 22 of Set 4 | coruripe
# Processing Record 23 of Set 4 | castro
# Processing Record 24 of Set 4 | eldorado
# Processing Record 25 of Set 4 | goure
# Processing Record 26 of Set 4 | brae
# Processing Record 27 of Set 4 | pangai
# Processing Record 28 of Set 4 | biak
# Processing Record 29 of Set 4 | abha
# Processing Record 30 of Set 4 | dakar
# Processing Record 31 of Set 4 | qaqortoq
# Processing Record 32 of Set 4 | saint george
# Processing Record 33 of Set 4 | puerto escondido
# Processing Record 34 of Set 4 | umm lajj
# Processing Record 35 of Set 4 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 36 of Set 4 | westport
# Processing Record 37 of Set 4 | jalu
# Processing Record 38 of Set 4 | alice springs
# Processing Record 39 of Set 4 | troitskoye
# Processing Record 40 of Set 4 | chagda
# City not found. Skipping...
# Processing Record 41 of Set 4 | nouadhibou
# Processing Record 42 of Set 4 | great bend
# Processing Record 43 of Set 4 | payson
# Processing Record 44 of Set 4 | hay river
# Processing Record 45 of Set 4 | tura
# Processing Record 46 of Set 4 | artyk
# City not found. Skipping...
# Processing Record 47 of Set 4 | amapa
# Processing Record 48 of Set 4 | miri
# Processing Record 49 of Set 4 | nishihara
# Processing Record 50 of Set 4 | ostrovnoy
# Processing Record 1 of Set 5 | sataua
# City not found. Skipping...
# Processing Record 2 of Set 5 | grao mogol
# Processing Record 3 of Set 5 | kutum
# Processing Record 4 of Set 5 | nogent-le-rotrou
# Processing Record 5 of Set 5 | iksha
# Processing Record 6 of Set 5 | lodja
# Processing Record 7 of Set 5 | san matias
# Processing Record 8 of Set 5 | cap malheureux
# Processing Record 9 of Set 5 | pontian kecil
# Processing Record 10 of Set 5 | kasongo-lunda
# Processing Record 11 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 12 of Set 5 | redlands
# Processing Record 13 of Set 5 | calvia
# Processing Record 14 of Set 5 | vila franca do campo
# Processing Record 15 of Set 5 | ketchikan
# Processing Record 16 of Set 5 | la asuncion
# Processing Record 17 of Set 5 | torbay
# Processing Record 18 of Set 5 | toliary
# City not found. Skipping...
# Processing Record 19 of Set 5 | san carlos
# Processing Record 20 of Set 5 | dalby
# Processing Record 21 of Set 5 | santa ines
# Processing Record 22 of Set 5 | iquique
# Processing Record 23 of Set 5 | sur
# Processing Record 24 of Set 5 | tabiauea
# City not found. Skipping...
# Processing Record 25 of Set 5 | guipavas
# Processing Record 26 of Set 5 | sorland
# Processing Record 27 of Set 5 | zeya
# Processing Record 28 of Set 5 | kaeo
# Processing Record 29 of Set 5 | port said
# Processing Record 30 of Set 5 | parvatipuram
# Processing Record 31 of Set 5 | kaputa
# Processing Record 32 of Set 5 | camana
# Processing Record 33 of Set 5 | rio grande
# Processing Record 34 of Set 5 | kahului
# Processing Record 35 of Set 5 | alenquer
# Processing Record 36 of Set 5 | buin
# Processing Record 37 of Set 5 | kuytun
# Processing Record 38 of Set 5 | yithion
# City not found. Skipping...
# Processing Record 39 of Set 5 | norman wells
# Processing Record 40 of Set 5 | ribeira grande
# Processing Record 41 of Set 5 | bilibino
# Processing Record 42 of Set 5 | juneau
# Processing Record 43 of Set 5 | maragogi
# Processing Record 44 of Set 5 | tibati
# Processing Record 45 of Set 5 | akure
# Processing Record 46 of Set 5 | yei
# Processing Record 47 of Set 5 | manoel urbano
# Processing Record 48 of Set 5 | saskylakh
# Processing Record 49 of Set 5 | henties bay
# Processing Record 50 of Set 5 | cestas
# Processing Record 1 of Set 6 | lusambo
# Processing Record 2 of Set 6 | paamiut
# Processing Record 3 of Set 6 | rastolita
# Processing Record 4 of Set 6 | nanortalik
# Processing Record 5 of Set 6 | pilao arcado
# City not found. Skipping...
# Processing Record 6 of Set 6 | jiangyou
# Processing Record 7 of Set 6 | constitucion
# Processing Record 8 of Set 6 | san cristobal
# Processing Record 9 of Set 6 | paita
# Processing Record 10 of Set 6 | ziro
# Processing Record 11 of Set 6 | wilmington
# Processing Record 12 of Set 6 | buqayq
# City not found. Skipping...
# Processing Record 13 of Set 6 | poum
# Processing Record 14 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 15 of Set 6 | oranjestad
# Processing Record 16 of Set 6 | hithadhoo
# Processing Record 17 of Set 6 | tabou
# Processing Record 18 of Set 6 | mount gambier
# Processing Record 19 of Set 6 | huilong
# Processing Record 20 of Set 6 | los llanos de aridane
# Processing Record 21 of Set 6 | loandjili
# Processing Record 22 of Set 6 | sokolka
# Processing Record 23 of Set 6 | saint anthony
# Processing Record 24 of Set 6 | laguna
# Processing Record 25 of Set 6 | kiruna
# Processing Record 26 of Set 6 | aklavik
# Processing Record 27 of Set 6 | terney
# Processing Record 28 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 29 of Set 6 | port alfred
# Processing Record 30 of Set 6 | belomorsk
# Processing Record 31 of Set 6 | agadez
# Processing Record 32 of Set 6 | agirish
# Processing Record 33 of Set 6 | jiwani
# Processing Record 34 of Set 6 | victoria
# Processing Record 35 of Set 6 | antofagasta
# Processing Record 36 of Set 6 | brindisi
# Processing Record 37 of Set 6 | catamarca
# Processing Record 38 of Set 6 | oranjemund
# Processing Record 39 of Set 6 | cururupu
# Processing Record 40 of Set 6 | zhangzhou
# Processing Record 41 of Set 6 | vardo
# Processing Record 42 of Set 6 | kavieng
# Processing Record 43 of Set 6 | faanui
# Processing Record 44 of Set 6 | judenburg
# Processing Record 45 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 46 of Set 6 | zhigansk
# Processing Record 47 of Set 6 | igarka
# Processing Record 48 of Set 6 | yaring
# Processing Record 49 of Set 6 | kanina
# Processing Record 50 of Set 6 | margate
# Processing Record 1 of Set 7 | doorn
# Processing Record 2 of Set 7 | araguari
# Processing Record 3 of Set 7 | aswan
# Processing Record 4 of Set 7 | roma
# Processing Record 5 of Set 7 | upernavik
# Processing Record 6 of Set 7 | springside
# Processing Record 7 of Set 7 | mumford
# Processing Record 8 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 9 of Set 7 | smolenka
# Processing Record 10 of Set 7 | tomatlan
# Processing Record 11 of Set 7 | beringovskiy
# Processing Record 12 of Set 7 | curup
# Processing Record 13 of Set 7 | kardailovo
# Processing Record 14 of Set 7 | sakakah
# Processing Record 15 of Set 7 | san cosme y damian
# Processing Record 16 of Set 7 | quelimane
# Processing Record 17 of Set 7 | payo
# Processing Record 18 of Set 7 | darovskoy
# Processing Record 19 of Set 7 | vyshneve
# Processing Record 20 of Set 7 | souillac
# Processing Record 21 of Set 7 | bababe
# City not found. Skipping...
# Processing Record 22 of Set 7 | port-gentil
# Processing Record 23 of Set 7 | kuche
# City not found. Skipping...
# Processing Record 24 of Set 7 | kaitangata
# Processing Record 25 of Set 7 | sobolevo
# Processing Record 26 of Set 7 | skjervoy
# Processing Record 27 of Set 7 | halalo
# City not found. Skipping...
# Processing Record 28 of Set 7 | hobyo
# Processing Record 29 of Set 7 | kamenskoye
# City not found. Skipping...
# Processing Record 30 of Set 7 | egvekinot
# Processing Record 31 of Set 7 | moindou
# Processing Record 32 of Set 7 | jacareacanga
# Processing Record 33 of Set 7 | oistins
# Processing Record 34 of Set 7 | sioux lookout
# Processing Record 35 of Set 7 | lishui
# Processing Record 36 of Set 7 | nortelandia
# Processing Record 37 of Set 7 | talawdi
# City not found. Skipping...
# Processing Record 38 of Set 7 | linxia
# Processing Record 39 of Set 7 | walvis bay
# Processing Record 40 of Set 7 | lucea
# Processing Record 41 of Set 7 | one hundred mile house
# City not found. Skipping...
# Processing Record 42 of Set 7 | lithakia
# Processing Record 43 of Set 7 | orange
# Processing Record 44 of Set 7 | port hardy
# Processing Record 45 of Set 7 | azimur
# City not found. Skipping...
# Processing Record 46 of Set 7 | sept-iles
# Processing Record 47 of Set 7 | acapulco
# Processing Record 48 of Set 7 | rio rancho
# Processing Record 49 of Set 7 | tambura
# Processing Record 50 of Set 7 | honningsvag
# Processing Record 1 of Set 8 | staryy nadym
# Processing Record 2 of Set 8 | goya
# Processing Record 3 of Set 8 | ancud
# Processing Record 4 of Set 8 | derzhavinsk
# Processing Record 5 of Set 8 | arlit
# Processing Record 6 of Set 8 | el faiyum
# City not found. Skipping...
# Processing Record 7 of Set 8 | monrovia
# Processing Record 8 of Set 8 | ati
# Processing Record 9 of Set 8 | alibag
# Processing Record 10 of Set 8 | hualmay
# Processing Record 11 of Set 8 | saint marys
# Processing Record 12 of Set 8 | ambunti
# Processing Record 13 of Set 8 | doctor mora
# Processing Record 14 of Set 8 | pecos
# Processing Record 15 of Set 8 | kapuskasing
# Processing Record 16 of Set 8 | shache
# Processing Record 17 of Set 8 | leningradskiy
# Processing Record 18 of Set 8 | lompoc
# Processing Record 19 of Set 8 | saint-pierre
# Processing Record 20 of Set 8 | broome
# Processing Record 21 of Set 8 | saint-francois
# Processing Record 22 of Set 8 | rio gallegos
# Processing Record 23 of Set 8 | coolum beach
# Processing Record 24 of Set 8 | alta floresta
# Processing Record 25 of Set 8 | ilulissat
# Processing Record 26 of Set 8 | dingle
# Processing Record 27 of Set 8 | jiddah
# City not found. Skipping...
# Processing Record 28 of Set 8 | calama
# Processing Record 29 of Set 8 | porto santo
# Processing Record 30 of Set 8 | krasnoselkup
# Processing Record 31 of Set 8 | borogontsy
# Processing Record 32 of Set 8 | kandrian
# Processing Record 33 of Set 8 | rochester
# Processing Record 34 of Set 8 | coihaique
# Processing Record 35 of Set 8 | angoche
# Processing Record 36 of Set 8 | aragarcas
# Processing Record 37 of Set 8 | salou
# Processing Record 38 of Set 8 | ndele
# Processing Record 39 of Set 8 | okha
# Processing Record 40 of Set 8 | uruguaiana
# Processing Record 41 of Set 8 | sambava
# Processing Record 42 of Set 8 | achisay
# City not found. Skipping...
# Processing Record 43 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 44 of Set 8 | necochea
# Processing Record 45 of Set 8 | cayenne
# Processing Record 46 of Set 8 | tanete
# Processing Record 47 of Set 8 | kununurra
# Processing Record 48 of Set 8 | jizan
# Processing Record 49 of Set 8 | cidreira
# Processing Record 50 of Set 8 | sakaiminato
# Processing Record 1 of Set 9 | rayachoti
# Processing Record 2 of Set 9 | guadalupe victoria
# Processing Record 3 of Set 9 | haimen
# Processing Record 4 of Set 9 | muriwai beach
# Processing Record 5 of Set 9 | xingtai
# Processing Record 6 of Set 9 | port blair
# Processing Record 7 of Set 9 | erzin
# Processing Record 8 of Set 9 | cordoba
# Processing Record 9 of Set 9 | chiredzi
# Processing Record 10 of Set 9 | meiganga
# Processing Record 11 of Set 9 | te anau
# Processing Record 12 of Set 9 | liverpool
# Processing Record 13 of Set 9 | morondava
# Processing Record 14 of Set 9 | sokoni
# Processing Record 15 of Set 9 | salinopolis
# Processing Record 16 of Set 9 | toamasina
# Processing Record 17 of Set 9 | caravelas
# Processing Record 18 of Set 9 | lauda-konigshofen
# Processing Record 19 of Set 9 | inta
# Processing Record 20 of Set 9 | general roca
# Processing Record 21 of Set 9 | shimoda
# Processing Record 22 of Set 9 | eureka
# Processing Record 23 of Set 9 | abu dhabi
# Processing Record 24 of Set 9 | sitka
# Processing Record 25 of Set 9 | bhadrachalam
# Processing Record 26 of Set 9 | nicoya
# Processing Record 27 of Set 9 | fort wellington
# Processing Record 28 of Set 9 | rexburg
# Processing Record 29 of Set 9 | narsaq
# Processing Record 30 of Set 9 | canon city
# Processing Record 31 of Set 9 | karamea
# City not found. Skipping...
# Processing Record 32 of Set 9 | inuvik
# Processing Record 33 of Set 9 | tretten
# Processing Record 34 of Set 9 | abalak
# Processing Record 35 of Set 9 | luanda
# Processing Record 36 of Set 9 | banjar
# Processing Record 37 of Set 9 | bonfim
# Processing Record 38 of Set 9 | muros
# Processing Record 39 of Set 9 | guamal
# Processing Record 40 of Set 9 | oswego
# Processing Record 41 of Set 9 | lata
# Processing Record 42 of Set 9 | lumphat
# Processing Record 43 of Set 9 | diu
# Processing Record 44 of Set 9 | plettenberg bay
# Processing Record 45 of Set 9 | mezen
# Processing Record 46 of Set 9 | evanston
# Processing Record 47 of Set 9 | tuatapere
# Processing Record 48 of Set 9 | sao felix do xingu
# Processing Record 49 of Set 9 | gat
# Processing Record 50 of Set 9 | synya
# Processing Record 1 of Set 10 | husavik
# Processing Record 2 of Set 10 | monterey
# Processing Record 3 of Set 10 | cabo san lucas
# Processing Record 4 of Set 10 | chuy
# Processing Record 5 of Set 10 | bom jesus
# Processing Record 6 of Set 10 | dauphin
# Processing Record 7 of Set 10 | vao
# Processing Record 8 of Set 10 | aljezur
# Processing Record 9 of Set 10 | havre-saint-pierre
# Processing Record 10 of Set 10 | west bend
# Processing Record 11 of Set 10 | metehara
# City not found. Skipping...
# Processing Record 12 of Set 10 | yerbogachen
# Processing Record 13 of Set 10 | nantucket
# Processing Record 14 of Set 10 | iqaluit
# Processing Record 15 of Set 10 | sao joao da barra
# Processing Record 16 of Set 10 | boca do acre
# Processing Record 17 of Set 10 | hambantota
# Processing Record 18 of Set 10 | pacific grove
# Processing Record 19 of Set 10 | alakurtti
# Processing Record 20 of Set 10 | illapel
# Processing Record 21 of Set 10 | road town
# Processing Record 22 of Set 10 | port-de-paix
# City not found. Skipping...
# Processing Record 23 of Set 10 | hastings
# Processing Record 24 of Set 10 | comodoro rivadavia
# Processing Record 25 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 26 of Set 10 | zamora
# Processing Record 27 of Set 10 | marzuq
# Processing Record 28 of Set 10 | mortka
# Processing Record 29 of Set 10 | kendari
# Processing Record 30 of Set 10 | placido de castro
# Processing Record 31 of Set 10 | vestmanna
# Processing Record 32 of Set 10 | beeville
# Processing Record 33 of Set 10 | ksenyevka
# City not found. Skipping...
# Processing Record 34 of Set 10 | takoradi
# Processing Record 35 of Set 10 | svetlyy
# Processing Record 36 of Set 10 | sinnar
# Processing Record 37 of Set 10 | fortuna
# Processing Record 38 of Set 10 | san-pedro
# Processing Record 39 of Set 10 | xinan
# Processing Record 40 of Set 10 | tacuarembo
# Processing Record 41 of Set 10 | skibbereen
# Processing Record 42 of Set 10 | la ronge
# Processing Record 43 of Set 10 | sayhat
# Processing Record 44 of Set 10 | wulanhaote
# City not found. Skipping...
# Processing Record 45 of Set 10 | prnjavor
# Processing Record 46 of Set 10 | aksu
# Processing Record 47 of Set 10 | rocha
# Processing Record 48 of Set 10 | vostok
# Processing Record 49 of Set 10 | parauna
# Processing Record 50 of Set 10 | port arthur
# Processing Record 1 of Set 11 | kumertau
# Processing Record 2 of Set 11 | kattivakkam
# Processing Record 3 of Set 11 | bad freienwalde
# Processing Record 4 of Set 11 | trairi
# Processing Record 5 of Set 11 | xichang
# Processing Record 6 of Set 11 | russell
# Processing Record 7 of Set 11 | uba
# Processing Record 8 of Set 11 | hvolsvollur
# Processing Record 9 of Set 11 | yilan
# Processing Record 10 of Set 11 | piacabucu
# Processing Record 11 of Set 11 | jieshi
# Processing Record 12 of Set 11 | la macarena
# Processing Record 13 of Set 11 | guiyang
# Processing Record 14 of Set 11 | port macquarie
# Processing Record 15 of Set 11 | fort nelson
# Processing Record 16 of Set 11 | chipaque
# Processing Record 17 of Set 11 | lakatoro
# Processing Record 18 of Set 11 | shingu
# Processing Record 19 of Set 11 | sembe
# Processing Record 20 of Set 11 | grass valley
# Processing Record 21 of Set 11 | mountain home
# Processing Record 22 of Set 11 | cascais
# Processing Record 23 of Set 11 | oussouye
# Processing Record 24 of Set 11 | anadyr
# Processing Record 25 of Set 11 | broken hill
# Processing Record 26 of Set 11 | mulege
# Processing Record 27 of Set 11 | okhotsk
# Processing Record 28 of Set 11 | formoso do araguaia
# City not found. Skipping...
# Processing Record 29 of Set 11 | quimper
# Processing Record 30 of Set 11 | quatre cocos
# Processing Record 31 of Set 11 | bowen
# Processing Record 32 of Set 11 | namibe
# Processing Record 33 of Set 11 | sivas
# Processing Record 34 of Set 11 | phek
# Processing Record 35 of Set 11 | manacapuru
# Processing Record 36 of Set 11 | skole
# Processing Record 37 of Set 11 | siparia
# Processing Record 38 of Set 11 | mitchell
# Processing Record 39 of Set 11 | wukari
# Processing Record 40 of Set 11 | neiafu
# Processing Record 41 of Set 11 | gravelbourg
# Processing Record 42 of Set 11 | bandar-e lengeh
# Processing Record 43 of Set 11 | mehamn
# Processing Record 44 of Set 11 | vilyuysk
# Processing Record 45 of Set 11 | ardistan
# City not found. Skipping...
# Processing Record 46 of Set 11 | yulara
# Processing Record 47 of Set 11 | itanhem
# Processing Record 48 of Set 11 | suphan buri
# Processing Record 49 of Set 11 | mga
# Processing Record 50 of Set 11 | mponela
# Processing Record 1 of Set 12 | ciudad bolivar
# Processing Record 2 of Set 12 | ambon
# Processing Record 3 of Set 12 | togur
# Processing Record 4 of Set 12 | ambodifototra
# City not found. Skipping...
# Processing Record 5 of Set 12 | makakilo city
# Processing Record 6 of Set 12 | cockburn town
# Processing Record 7 of Set 12 | samarai
# Processing Record 8 of Set 12 | bhanpuri
# Processing Record 9 of Set 12 | itarema
# Processing Record 10 of Set 12 | funadhoo
# Processing Record 11 of Set 12 | puerto madryn
# Processing Record 12 of Set 12 | kibala
# Processing Record 13 of Set 12 | rosetta
# Processing Record 14 of Set 12 | kasaragod
# Processing Record 15 of Set 12 | koslan
# Processing Record 16 of Set 12 | beja
# Processing Record 17 of Set 12 | ous
# Processing Record 18 of Set 12 | coquimbo
# Processing Record 19 of Set 12 | burnie
# Processing Record 20 of Set 12 | banda aceh
# Processing Record 21 of Set 12 | diffa
# Processing Record 22 of Set 12 | mbanza-ngungu
# Processing Record 23 of Set 12 | barentu
# Processing Record 24 of Set 12 | tarko-sale
# Processing Record 25 of Set 12 | bilma
# Processing Record 26 of Set 12 | sigayevo
# Processing Record 27 of Set 12 | luce
# Processing Record 28 of Set 12 | mount darwin
# Processing Record 29 of Set 12 | louisbourg
# City not found. Skipping...
# Processing Record 30 of Set 12 | rorvik
# Processing Record 31 of Set 12 | slonim
# Processing Record 32 of Set 12 | san juan
# Processing Record 33 of Set 12 | sadao
# Processing Record 34 of Set 12 | ohara
# Processing Record 35 of Set 12 | alofi
# Processing Record 36 of Set 12 | panlaitan
# Processing Record 37 of Set 12 | kasangulu
# Processing Record 38 of Set 12 | gulfport
# Processing Record 39 of Set 12 | yanam
# Processing Record 40 of Set 12 | pahrump
# Processing Record 41 of Set 12 | tarudant
# City not found. Skipping...
# Processing Record 42 of Set 12 | bage
# Processing Record 43 of Set 12 | cartagena
# Processing Record 44 of Set 12 | jiuquan
# Processing Record 45 of Set 12 | haibowan
# City not found. Skipping...
# Processing Record 46 of Set 12 | palmer
# Processing Record 47 of Set 12 | burkhala
# City not found. Skipping...
# Processing Record 48 of Set 12 | abasolo
# Processing Record 49 of Set 12 | wilkie
# Processing Record 50 of Set 12 | heishan
# Processing Record 1 of Set 13 | roald
# Processing Record 2 of Set 13 | gourdon
# Processing Record 3 of Set 13 | benghazi
# Processing Record 4 of Set 13 | jardim
# Processing Record 5 of Set 13 | lalibela
# Processing Record 6 of Set 13 | balakhninskiy
# Processing Record 7 of Set 13 | kracheh
# City not found. Skipping...
# Processing Record 8 of Set 13 | tessalit
# Processing Record 9 of Set 13 | santiago
# Processing Record 10 of Set 13 | hofn
# Processing Record 11 of Set 13 | avera
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   Guerrero Negro  27.9769 -114.0611     58.23        71          50
# 1  South Yuba City  39.1166 -121.6391     52.00        58          90
# 2         Tasiilaq  65.6145  -37.6368     30.20        80          75
# 3      Tuktoyaktuk  69.4541 -133.0374     -7.60        77          90
# 4        Esperance -33.8667  121.9000     80.60        39          42
# 5            Kapaa  22.0752 -159.3190     78.80        73           1
# 6           Bethel  41.3712  -73.4140     32.00        64          20
# 7      East London -33.0153   27.9116     71.73        87          92
# 8        Busselton -33.6500  115.3333     86.00        54         100
# 9      Yellowknife  62.4560 -114.3525     -7.01        84           1
#
#    Wind Speed Country                 Date
# 0       14.36      MX  2021-02-15 02:28:30
# 1        5.75      US  2021-02-15 02:28:30
# 2        5.75      GL  2021-02-15 02:28:30
# 3        8.05      CA  2021-02-15 02:28:30
# 4        8.05      AU  2021-02-15 02:28:31
# 5       11.50      US  2021-02-15 02:28:31
# 6        4.61      US  2021-02-15 02:28:31
# 7       16.22      ZA  2021-02-15 02:28:31
# 8        1.01      AU  2021-02-15 02:28:31
# 9        9.22      CA  2021-02-15 02:28:31

# %%
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]

city_data_df = city_data_df[new_column_order]

city_data_df
# Out:
#                 City Country                 Date      Lat       Lng  \
# 0     Guerrero Negro      MX  2021-02-15 02:28:30  27.9769 -114.0611
# 1    South Yuba City      US  2021-02-15 02:28:30  39.1166 -121.6391
# 2           Tasiilaq      GL  2021-02-15 02:28:30  65.6145  -37.6368
# 3        Tuktoyaktuk      CA  2021-02-15 02:28:30  69.4541 -133.0374
# 4          Esperance      AU  2021-02-15 02:28:31 -33.8667  121.9000
# ..               ...     ...                  ...      ...       ...
# 550    Balakhninskiy      RU  2021-02-15 02:29:51  58.0106  114.2769
# 551         Tessalit      ML  2021-02-15 02:29:51  20.1986    1.0114
# 552         Santiago      CL  2021-02-15 02:25:18 -33.4569  -70.6483
# 553             Hofn      IS  2021-02-15 02:29:52  64.2539  -15.2082
# 554            Avera      US  2021-02-15 02:29:52  33.1940  -82.5271
#
#      Max Temp  Humidity  Cloudiness  Wind Speed
# 0       58.23        71          50       14.36
# 1       52.00        58          90        5.75
# 2       30.20        80          75        5.75
# 3       -7.60        77          90        8.05
# 4       80.60        39          42        8.05
# ..        ...       ...         ...         ...
# 550    -17.97        81          58        0.78
# 551     69.73        19           0       10.11
# 552     69.01        72           0       10.36
# 553     42.19        92         100       12.30
# 554     42.80        95          90        4.61
#
# [555 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
# Extract relevant fields from the DataFrame for plotting.
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %%
# Import time module
import time

# Build the scatter plot for latitude vs. max temperature.
plt.scatter(lats,
            max_temps,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Max Temperature "+ time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig1.png")

# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. humidity.
plt.scatter(lats,
            humidity,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig2.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. cloudiness.
plt.scatter(lats,
            cloudiness,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Cloudiness (%) "+ time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig3.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. wind speed.
plt.scatter(lats,
            wind_speed,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Wind Speed "+ time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig4.png")
# Show plot.
plt.show()

# %%
# Import linregress
from scipy.stats import linregress

# Create a function to create perform linear regression on the weather data
# and plot a regression line and the equation with the data.
def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):

    # Run regression on hemisphere weather data.
    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)

    # Calculate the regression line "y values" from the slope and intercept.
    regress_values = x_values * slope + intercept
    # Get the equation of the line.
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    # Create a scatter plot and plot the regression line.
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r")
    # Annotate the text for the line equation.
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
    plt.xlabel('Latitude')
    plt.ylabel(y_label)
    plt.show()

# %%
index13 = city_data_df.loc[13]
index13
# Out:
# City                      Rikitea
# Country                        PF
# Date          2021-02-15 02:28:32
# Lat                      -23.1203
# Lng                      -134.969
# Max Temp                    80.24
# Humidity                       76
# Cloudiness                     55
# Wind Speed                  16.55
# Name: 13, dtype: object

# %%
city_data_df["Lat"] >= 0
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4      False
#        ...
# 550     True
# 551     True
# 552    False
# 553     True
# 554     True
# Name: Lat, Length: 555, dtype: bool

# %%
city_data_df.loc[(city_data_df["Lat"] >= 0)].head()
# Out:
#               City Country                 Date      Lat       Lng  Max Temp  \
# 0   Guerrero Negro      MX  2021-02-15 02:28:30  27.9769 -114.0611     58.23
# 1  South Yuba City      US  2021-02-15 02:28:30  39.1166 -121.6391     52.00
# 2         Tasiilaq      GL  2021-02-15 02:28:30  65.6145  -37.6368     30.20
# 3      Tuktoyaktuk      CA  2021-02-15 02:28:30  69.4541 -133.0374     -7.60
# 5            Kapaa      US  2021-02-15 02:28:31  22.0752 -159.3190     78.80
#
#    Humidity  Cloudiness  Wind Speed
# 0        71          50       14.36
# 1        58          90        5.75
# 2        80          75        5.75
# 3        77          90        8.05
# 5        73           1       11.50

# %%
# Create Northern and Southern Hemisphere DataFrames.
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] < 0)]

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for Maximum Temperature', 'Max Temp',(0,0))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for Maximum Temperature', 'Max Temp',(-50,55))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for % Humidity', '% Humidity',(40,20))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for % Humidity', '% Humidity',(-50,15))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for % Cloudiness', '% Cloudiness',(40,20))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \n'
                        'for % Cloudiness', '% Cloudiness',(-50,60))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \n'
                        'for Wind Speed', 'Wind Speed',(40,30))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \n'
                        'for Wind Speed', 'Wind Speed',(-50,30))

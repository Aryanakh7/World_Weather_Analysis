# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 610

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | lorengau
# Processing Record 2 of Set 1 | punta arenas
# Processing Record 3 of Set 1 | cururupu
# Processing Record 4 of Set 1 | new norfolk
# Processing Record 5 of Set 1 | albany
# Processing Record 6 of Set 1 | lebu
# Processing Record 7 of Set 1 | cherskiy
# Processing Record 8 of Set 1 | ilulissat
# Processing Record 9 of Set 1 | norman wells
# Processing Record 10 of Set 1 | lasa
# Processing Record 11 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 12 of Set 1 | haines junction
# Processing Record 13 of Set 1 | aykhal
# Processing Record 14 of Set 1 | fredericksburg
# Processing Record 15 of Set 1 | mataura
# Processing Record 16 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 17 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 18 of Set 1 | jamestown
# Processing Record 19 of Set 1 | saint-philippe
# Processing Record 20 of Set 1 | nanortalik
# Processing Record 21 of Set 1 | hithadhoo
# Processing Record 22 of Set 1 | yellowknife
# Processing Record 23 of Set 1 | san andres
# Processing Record 24 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 25 of Set 1 | port alfred
# Processing Record 26 of Set 1 | ukiah
# Processing Record 27 of Set 1 | mrirt
# City not found. Skipping...
# Processing Record 28 of Set 1 | cape town
# Processing Record 29 of Set 1 | pangnirtung
# Processing Record 30 of Set 1 | vaini
# Processing Record 31 of Set 1 | tiksi
# Processing Record 32 of Set 1 | vao
# Processing Record 33 of Set 1 | bredasdorp
# Processing Record 34 of Set 1 | qaanaaq
# Processing Record 35 of Set 1 | barrow
# Processing Record 36 of Set 1 | havre-saint-pierre
# Processing Record 37 of Set 1 | bambous virieux
# Processing Record 38 of Set 1 | rikitea
# Processing Record 39 of Set 1 | ushuaia
# Processing Record 40 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 41 of Set 1 | klaksvik
# Processing Record 42 of Set 1 | north bend
# Processing Record 43 of Set 1 | abu kamal
# Processing Record 44 of Set 1 | gat
# Processing Record 45 of Set 1 | saldanha
# Processing Record 46 of Set 1 | bollnas
# Processing Record 47 of Set 1 | hermanus
# Processing Record 48 of Set 1 | carballo
# Processing Record 49 of Set 1 | thayetmyo
# Processing Record 50 of Set 1 | torring
# Processing Record 1 of Set 2 | kavieng
# Processing Record 2 of Set 2 | hobart
# Processing Record 3 of Set 2 | borborema
# Processing Record 4 of Set 2 | thompson
# Processing Record 5 of Set 2 | aksarka
# Processing Record 6 of Set 2 | tuatapere
# Processing Record 7 of Set 2 | rafaela
# Processing Record 8 of Set 2 | sakakah
# Processing Record 9 of Set 2 | bowen
# Processing Record 10 of Set 2 | iqaluit
# Processing Record 11 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 12 of Set 2 | dikson
# Processing Record 13 of Set 2 | quatre cocos
# Processing Record 14 of Set 2 | esperance
# Processing Record 15 of Set 2 | la rioja
# Processing Record 16 of Set 2 | margate
# Processing Record 17 of Set 2 | morgan city
# Processing Record 18 of Set 2 | cockburn town
# Processing Record 19 of Set 2 | avarua
# Processing Record 20 of Set 2 | geraldton
# Processing Record 21 of Set 2 | bluff
# Processing Record 22 of Set 2 | boda
# Processing Record 23 of Set 2 | georgetown
# Processing Record 24 of Set 2 | mahebourg
# Processing Record 25 of Set 2 | anar darreh
# City not found. Skipping...
# Processing Record 26 of Set 2 | reforma
# Processing Record 27 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 28 of Set 2 | kalabo
# Processing Record 29 of Set 2 | cotonou
# Processing Record 30 of Set 2 | kaitangata
# Processing Record 31 of Set 2 | fortuna
# Processing Record 32 of Set 2 | kitui
# Processing Record 33 of Set 2 | samarai
# Processing Record 34 of Set 2 | yar-sale
# Processing Record 35 of Set 2 | hualmay
# Processing Record 36 of Set 2 | daugavpils
# Processing Record 37 of Set 2 | dalbandin
# Processing Record 38 of Set 2 | kapaa
# Processing Record 39 of Set 2 | atuona
# Processing Record 40 of Set 2 | clyde river
# Processing Record 41 of Set 2 | mountain home
# Processing Record 42 of Set 2 | minot
# Processing Record 43 of Set 2 | sorvag
# City not found. Skipping...
# Processing Record 44 of Set 2 | sur
# Processing Record 45 of Set 2 | kodiak
# Processing Record 46 of Set 2 | upernavik
# Processing Record 47 of Set 2 | bonthe
# Processing Record 48 of Set 2 | waipawa
# Processing Record 49 of Set 2 | bubaque
# Processing Record 50 of Set 2 | maymyo
# Processing Record 1 of Set 3 | fayaoue
# Processing Record 2 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 3 of Set 3 | kiama
# Processing Record 4 of Set 3 | nicoya
# Processing Record 5 of Set 3 | ca mau
# Processing Record 6 of Set 3 | naze
# Processing Record 7 of Set 3 | oktyabrskiy
# Processing Record 8 of Set 3 | palmer
# Processing Record 9 of Set 3 | lavrentiya
# Processing Record 10 of Set 3 | macaboboni
# City not found. Skipping...
# Processing Record 11 of Set 3 | gobabis
# Processing Record 12 of Set 3 | kruisfontein
# Processing Record 13 of Set 3 | tual
# Processing Record 14 of Set 3 | itoman
# Processing Record 15 of Set 3 | mount gambier
# Processing Record 16 of Set 3 | havelock
# Processing Record 17 of Set 3 | verkhnyaya inta
# Processing Record 18 of Set 3 | aksu
# Processing Record 19 of Set 3 | tommot
# Processing Record 20 of Set 3 | sisimiut
# Processing Record 21 of Set 3 | waingapu
# Processing Record 22 of Set 3 | qingdao
# Processing Record 23 of Set 3 | khatanga
# Processing Record 24 of Set 3 | yashkul
# Processing Record 25 of Set 3 | karamea
# City not found. Skipping...
# Processing Record 26 of Set 3 | arraial do cabo
# Processing Record 27 of Set 3 | rawson
# Processing Record 28 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 29 of Set 3 | fukue
# Processing Record 30 of Set 3 | ribeira grande
# Processing Record 31 of Set 3 | batsfjord
# Processing Record 32 of Set 3 | rungata
# City not found. Skipping...
# Processing Record 33 of Set 3 | marsh harbour
# Processing Record 34 of Set 3 | port elizabeth
# Processing Record 35 of Set 3 | outlook
# Processing Record 36 of Set 3 | ponta do sol
# Processing Record 37 of Set 3 | east london
# Processing Record 38 of Set 3 | keti bandar
# Processing Record 39 of Set 3 | tarata
# Processing Record 40 of Set 3 | sao joao da barra
# Processing Record 41 of Set 3 | ponta delgada
# Processing Record 42 of Set 3 | bethel
# Processing Record 43 of Set 3 | buala
# Processing Record 44 of Set 3 | mukhen
# Processing Record 45 of Set 3 | issenye
# Processing Record 46 of Set 3 | longyearbyen
# Processing Record 47 of Set 3 | moyamba
# Processing Record 48 of Set 3 | cidreira
# Processing Record 49 of Set 3 | louisbourg
# City not found. Skipping...
# Processing Record 50 of Set 3 | estelle
# Processing Record 1 of Set 4 | kenora
# Processing Record 2 of Set 4 | hovd
# Processing Record 3 of Set 4 | egvekinot
# Processing Record 4 of Set 4 | ocara
# Processing Record 5 of Set 4 | port-gentil
# Processing Record 6 of Set 4 | oranjemund
# Processing Record 7 of Set 4 | busselton
# Processing Record 8 of Set 4 | saskylakh
# Processing Record 9 of Set 4 | butaritari
# Processing Record 10 of Set 4 | taunggyi
# Processing Record 11 of Set 4 | san pedro
# Processing Record 12 of Set 4 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 13 of Set 4 | nelson bay
# Processing Record 14 of Set 4 | zeya
# Processing Record 15 of Set 4 | jinchang
# Processing Record 16 of Set 4 | chuy
# Processing Record 17 of Set 4 | parintins
# Processing Record 18 of Set 4 | aklavik
# Processing Record 19 of Set 4 | komsomolskiy
# Processing Record 20 of Set 4 | chiang rai
# Processing Record 21 of Set 4 | isangel
# Processing Record 22 of Set 4 | beringovskiy
# Processing Record 23 of Set 4 | bac lieu
# Processing Record 24 of Set 4 | campoverde
# Processing Record 25 of Set 4 | laguna
# Processing Record 26 of Set 4 | maine-soroa
# Processing Record 27 of Set 4 | evreux
# Processing Record 28 of Set 4 | carutapera
# Processing Record 29 of Set 4 | bengkulu
# Processing Record 30 of Set 4 | umba
# Processing Record 31 of Set 4 | general roca
# Processing Record 32 of Set 4 | taree
# Processing Record 33 of Set 4 | riyadh
# Processing Record 34 of Set 4 | torbay
# Processing Record 35 of Set 4 | svetlogorsk
# Processing Record 36 of Set 4 | saint george
# Processing Record 37 of Set 4 | cabo san lucas
# Processing Record 38 of Set 4 | bira
# Processing Record 39 of Set 4 | ola
# Processing Record 40 of Set 4 | hihifo
# City not found. Skipping...
# Processing Record 41 of Set 4 | katsuura
# Processing Record 42 of Set 4 | rio tercero
# Processing Record 43 of Set 4 | khao yoi
# Processing Record 44 of Set 4 | iralaya
# Processing Record 45 of Set 4 | ushtobe
# Processing Record 46 of Set 4 | santo tomas
# Processing Record 47 of Set 4 | provideniya
# Processing Record 48 of Set 4 | agirish
# Processing Record 49 of Set 4 | mecca
# Processing Record 50 of Set 4 | idlib
# Processing Record 1 of Set 5 | turtas
# Processing Record 2 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 3 of Set 5 | victoria
# Processing Record 4 of Set 5 | tarakan
# Processing Record 5 of Set 5 | tuktoyaktuk
# Processing Record 6 of Set 5 | maniitsoq
# Processing Record 7 of Set 5 | avera
# Processing Record 8 of Set 5 | anori
# Processing Record 9 of Set 5 | hami
# Processing Record 10 of Set 5 | salalah
# Processing Record 11 of Set 5 | matagami
# Processing Record 12 of Set 5 | ahipara
# Processing Record 13 of Set 5 | hasaki
# Processing Record 14 of Set 5 | baghmara
# Processing Record 15 of Set 5 | nago
# Processing Record 16 of Set 5 | ballina
# Processing Record 17 of Set 5 | tadine
# Processing Record 18 of Set 5 | gravdal
# Processing Record 19 of Set 5 | carnarvon
# Processing Record 20 of Set 5 | phan rang
# City not found. Skipping...
# Processing Record 21 of Set 5 | homer
# Processing Record 22 of Set 5 | bilma
# Processing Record 23 of Set 5 | susehri
# Processing Record 24 of Set 5 | nikolskoye
# Processing Record 25 of Set 5 | garmsar
# Processing Record 26 of Set 5 | kasangulu
# Processing Record 27 of Set 5 | onalaska
# Processing Record 28 of Set 5 | belyy yar
# Processing Record 29 of Set 5 | flin flon
# Processing Record 30 of Set 5 | poros
# Processing Record 31 of Set 5 | beverley
# Processing Record 32 of Set 5 | angoram
# Processing Record 33 of Set 5 | mar del plata
# Processing Record 34 of Set 5 | nagar karnul
# Processing Record 35 of Set 5 | opuwo
# Processing Record 36 of Set 5 | russellville
# Processing Record 37 of Set 5 | san quintin
# Processing Record 38 of Set 5 | grandview
# Processing Record 39 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 40 of Set 5 | la ferte-bernard
# Processing Record 41 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 42 of Set 5 | luderitz
# Processing Record 43 of Set 5 | sterling
# Processing Record 44 of Set 5 | narsaq
# Processing Record 45 of Set 5 | pasni
# Processing Record 46 of Set 5 | chokurdakh
# Processing Record 47 of Set 5 | nueva helvecia
# Processing Record 48 of Set 5 | cascais
# Processing Record 49 of Set 5 | karaul
# City not found. Skipping...
# Processing Record 50 of Set 5 | port hardy
# Processing Record 1 of Set 6 | karangsembung
# Processing Record 2 of Set 6 | goundam
# Processing Record 3 of Set 6 | codrington
# Processing Record 4 of Set 6 | sao miguel do araguaia
# Processing Record 5 of Set 6 | luwuk
# Processing Record 6 of Set 6 | pangkalanbuun
# Processing Record 7 of Set 6 | kieta
# Processing Record 8 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 9 of Set 6 | tura
# Processing Record 10 of Set 6 | maldonado
# Processing Record 11 of Set 6 | san carlos de bariloche
# Processing Record 12 of Set 6 | maragogi
# Processing Record 13 of Set 6 | hanzhong
# Processing Record 14 of Set 6 | nouakchott
# Processing Record 15 of Set 6 | pisco
# Processing Record 16 of Set 6 | natal
# Processing Record 17 of Set 6 | dawlatabad
# Processing Record 18 of Set 6 | coahuayana
# Processing Record 19 of Set 6 | basco
# Processing Record 20 of Set 6 | hilo
# Processing Record 21 of Set 6 | wajima
# Processing Record 22 of Set 6 | valparaiso
# Processing Record 23 of Set 6 | changtu
# Processing Record 24 of Set 6 | airai
# Processing Record 25 of Set 6 | vila
# Processing Record 26 of Set 6 | nome
# Processing Record 27 of Set 6 | reggello
# Processing Record 28 of Set 6 | puerto ayora
# Processing Record 29 of Set 6 | faanui
# Processing Record 30 of Set 6 | tabiauea
# City not found. Skipping...
# Processing Record 31 of Set 6 | magistralnyy
# Processing Record 32 of Set 6 | huangmei
# Processing Record 33 of Set 6 | labuhan
# Processing Record 34 of Set 6 | hamilton
# Processing Record 35 of Set 6 | warragul
# Processing Record 36 of Set 6 | matara
# Processing Record 37 of Set 6 | plettenberg bay
# Processing Record 38 of Set 6 | guerrero negro
# Processing Record 39 of Set 6 | inhambane
# Processing Record 40 of Set 6 | karakendzha
# City not found. Skipping...
# Processing Record 41 of Set 6 | cabedelo
# Processing Record 42 of Set 6 | san patricio
# Processing Record 43 of Set 6 | alofi
# Processing Record 44 of Set 6 | winslow
# Processing Record 45 of Set 6 | talnakh
# Processing Record 46 of Set 6 | najran
# Processing Record 47 of Set 6 | elat
# Processing Record 48 of Set 6 | northam
# Processing Record 49 of Set 6 | sao filipe
# Processing Record 50 of Set 6 | skibbereen
# Processing Record 1 of Set 7 | sal rei
# Processing Record 2 of Set 7 | rawannawi
# City not found. Skipping...
# Processing Record 3 of Set 7 | sept-iles
# Processing Record 4 of Set 7 | moerai
# Processing Record 5 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 6 of Set 7 | san ramon
# Processing Record 7 of Set 7 | poitiers
# Processing Record 8 of Set 7 | pangai
# Processing Record 9 of Set 7 | ocampo
# Processing Record 10 of Set 7 | dujuma
# City not found. Skipping...
# Processing Record 11 of Set 7 | tasiilaq
# Processing Record 12 of Set 7 | khandyga
# Processing Record 13 of Set 7 | rio gallegos
# Processing Record 14 of Set 7 | tessalit
# Processing Record 15 of Set 7 | bathsheba
# Processing Record 16 of Set 7 | dubai
# Processing Record 17 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 18 of Set 7 | castro
# Processing Record 19 of Set 7 | vila franca do campo
# Processing Record 20 of Set 7 | imeni poliny osipenko
# Processing Record 21 of Set 7 | severo-kurilsk
# Processing Record 22 of Set 7 | fereydun kenar
# Processing Record 23 of Set 7 | camrose
# Processing Record 24 of Set 7 | souillac
# Processing Record 25 of Set 7 | ancud
# Processing Record 26 of Set 7 | marshfield
# Processing Record 27 of Set 7 | saint-joseph
# Processing Record 28 of Set 7 | yarega
# Processing Record 29 of Set 7 | portland
# Processing Record 30 of Set 7 | swan hill
# Processing Record 31 of Set 7 | nkhotakota
# Processing Record 32 of Set 7 | anshun
# Processing Record 33 of Set 7 | vestmanna
# Processing Record 34 of Set 7 | tuburan
# Processing Record 35 of Set 7 | camacha
# Processing Record 36 of Set 7 | guerande
# Processing Record 37 of Set 7 | fereydunshahr
# Processing Record 38 of Set 7 | paracuru
# Processing Record 39 of Set 7 | yerbogachen
# Processing Record 40 of Set 7 | guanare
# Processing Record 41 of Set 7 | shache
# Processing Record 42 of Set 7 | husavik
# Processing Record 43 of Set 7 | faya
# Processing Record 44 of Set 7 | elverum
# Processing Record 45 of Set 7 | elvange
# Processing Record 46 of Set 7 | kralendijk
# Processing Record 47 of Set 7 | poya
# Processing Record 48 of Set 7 | limbang
# Processing Record 49 of Set 7 | boshkengash
# Processing Record 50 of Set 7 | westport
# Processing Record 1 of Set 8 | mandalgarh
# Processing Record 2 of Set 8 | road town
# Processing Record 3 of Set 8 | jumla
# Processing Record 4 of Set 8 | shenjiamen
# Processing Record 5 of Set 8 | salinopolis
# Processing Record 6 of Set 8 | bairiki
# Processing Record 7 of Set 8 | zhanakorgan
# Processing Record 8 of Set 8 | mitsamiouli
# Processing Record 9 of Set 8 | san luis
# Processing Record 10 of Set 8 | alice springs
# Processing Record 11 of Set 8 | ouallam
# Processing Record 12 of Set 8 | tilichiki
# Processing Record 13 of Set 8 | maceio
# Processing Record 14 of Set 8 | bonnyville
# Processing Record 15 of Set 8 | ternate
# Processing Record 16 of Set 8 | prudy
# Processing Record 17 of Set 8 | skalistyy
# City not found. Skipping...
# Processing Record 18 of Set 8 | te anau
# Processing Record 19 of Set 8 | srednekolymsk
# Processing Record 20 of Set 8 | argir
# Processing Record 21 of Set 8 | broken hill
# Processing Record 22 of Set 8 | bose
# Processing Record 23 of Set 8 | hauterive
# Processing Record 24 of Set 8 | ossora
# Processing Record 25 of Set 8 | prosvet
# Processing Record 26 of Set 8 | nouadhibou
# Processing Record 27 of Set 8 | katobu
# Processing Record 28 of Set 8 | kahului
# Processing Record 29 of Set 8 | vikulovo
# Processing Record 30 of Set 8 | kerrobert
# Processing Record 31 of Set 8 | diego de almagro
# Processing Record 32 of Set 8 | college
# Processing Record 33 of Set 8 | formoso do araguaia
# City not found. Skipping...
# Processing Record 34 of Set 8 | masjed-e soleyman
# City not found. Skipping...
# Processing Record 35 of Set 8 | asau
# Processing Record 36 of Set 8 | teahupoo
# Processing Record 37 of Set 8 | pevek
# Processing Record 38 of Set 8 | chaa-khol
# City not found. Skipping...
# Processing Record 39 of Set 8 | jasper
# Processing Record 40 of Set 8 | meulaboh
# Processing Record 41 of Set 8 | sechura
# Processing Record 42 of Set 8 | batemans bay
# Processing Record 43 of Set 8 | el rosario
# Processing Record 44 of Set 8 | barra do garcas
# Processing Record 45 of Set 8 | walvis bay
# Processing Record 46 of Set 8 | shahreza
# Processing Record 47 of Set 8 | blacksburg
# Processing Record 48 of Set 8 | padang
# Processing Record 49 of Set 8 | angoche
# Processing Record 50 of Set 8 | la ronge
# Processing Record 1 of Set 9 | chachapoyas
# Processing Record 2 of Set 9 | lalomanu
# City not found. Skipping...
# Processing Record 3 of Set 9 | bulgan
# Processing Record 4 of Set 9 | yamada
# Processing Record 5 of Set 9 | rongcheng
# Processing Record 6 of Set 9 | karratha
# Processing Record 7 of Set 9 | zhmerynka
# Processing Record 8 of Set 9 | sao miguel do iguacu
# Processing Record 9 of Set 9 | sabang
# Processing Record 10 of Set 9 | kloulklubed
# Processing Record 11 of Set 9 | mana
# Processing Record 12 of Set 9 | stephenville
# Processing Record 13 of Set 9 | aswan
# Processing Record 14 of Set 9 | neuquen
# Processing Record 15 of Set 9 | henties bay
# Processing Record 16 of Set 9 | wulanhaote
# City not found. Skipping...
# Processing Record 17 of Set 9 | sahrak
# City not found. Skipping...
# Processing Record 18 of Set 9 | meadow lake
# Processing Record 19 of Set 9 | touros
# Processing Record 20 of Set 9 | taltal
# Processing Record 21 of Set 9 | lancaster
# Processing Record 22 of Set 9 | zhanjiang
# Processing Record 23 of Set 9 | mattru
# Processing Record 24 of Set 9 | agadez
# Processing Record 25 of Set 9 | itatiaia
# Processing Record 26 of Set 9 | hesla
# Processing Record 27 of Set 9 | coquimbo
# Processing Record 28 of Set 9 | inirida
# Processing Record 29 of Set 9 | valdosta
# Processing Record 30 of Set 9 | abbeville
# Processing Record 31 of Set 9 | port hueneme
# Processing Record 32 of Set 9 | aki
# Processing Record 33 of Set 9 | nautla
# Processing Record 34 of Set 9 | mutsamudu
# City not found. Skipping...
# Processing Record 35 of Set 9 | ust-kan
# Processing Record 36 of Set 9 | nishihara
# Processing Record 37 of Set 9 | atar
# Processing Record 38 of Set 9 | vardo
# Processing Record 39 of Set 9 | sitka
# Processing Record 40 of Set 9 | milkovo
# Processing Record 41 of Set 9 | yarada
# Processing Record 42 of Set 9 | bow island
# Processing Record 43 of Set 9 | leningradskiy
# Processing Record 44 of Set 9 | puerto madryn
# Processing Record 45 of Set 9 | pailon
# Processing Record 46 of Set 9 | yumen
# Processing Record 47 of Set 9 | hofn
# Processing Record 48 of Set 9 | braslav
# City not found. Skipping...
# Processing Record 49 of Set 9 | saint-pierre
# Processing Record 50 of Set 9 | dabakala
# Processing Record 1 of Set 10 | gold coast
# Processing Record 2 of Set 10 | chardara
# Processing Record 3 of Set 10 | minab
# Processing Record 4 of Set 10 | atasu
# Processing Record 5 of Set 10 | nanakuli
# Processing Record 6 of Set 10 | rach gia
# Processing Record 7 of Set 10 | billings
# Processing Record 8 of Set 10 | saint-augustin
# Processing Record 9 of Set 10 | aberdeen
# Processing Record 10 of Set 10 | kenai
# Processing Record 11 of Set 10 | shetpe
# Processing Record 12 of Set 10 | nguiu
# City not found. Skipping...
# Processing Record 13 of Set 10 | youghal
# Processing Record 14 of Set 10 | gimli
# Processing Record 15 of Set 10 | krasnyy yar
# Processing Record 16 of Set 10 | lagos
# Processing Record 17 of Set 10 | bolungarvik
# City not found. Skipping...
# Processing Record 18 of Set 10 | hat yai
# Processing Record 19 of Set 10 | zaozerne
# Processing Record 20 of Set 10 | samusu
# City not found. Skipping...
# Processing Record 21 of Set 10 | omsukchan
# Processing Record 22 of Set 10 | ambilobe
# Processing Record 23 of Set 10 | elban
# Processing Record 24 of Set 10 | verkhnevilyuysk
# Processing Record 25 of Set 10 | gambo
# Processing Record 26 of Set 10 | ostrovnoy
# Processing Record 27 of Set 10 | flinders
# Processing Record 28 of Set 10 | novyy urengoy
# Processing Record 29 of Set 10 | mayumba
# Processing Record 30 of Set 10 | strezhevoy
# Processing Record 31 of Set 10 | manicore
# Processing Record 32 of Set 10 | poum
# Processing Record 33 of Set 10 | pangoa
# Processing Record 34 of Set 10 | paso de los toros
# Processing Record 35 of Set 10 | benguela
# Processing Record 36 of Set 10 | kaseda
# Processing Record 37 of Set 10 | praia
# Processing Record 38 of Set 10 | kavaratti
# Processing Record 39 of Set 10 | manaure
# Processing Record 40 of Set 10 | charters towers
# Processing Record 41 of Set 10 | korhogo
# Processing Record 42 of Set 10 | gizo
# Processing Record 43 of Set 10 | kabanjahe
# Processing Record 44 of Set 10 | allanmyo
# City not found. Skipping...
# Processing Record 45 of Set 10 | nenagh
# Processing Record 46 of Set 10 | piterka
# Processing Record 47 of Set 10 | mormugao
# Processing Record 48 of Set 10 | sena madureira
# Processing Record 49 of Set 10 | nuuk
# Processing Record 50 of Set 10 | fairbanks
# Processing Record 1 of Set 11 | adrar
# Processing Record 2 of Set 11 | rumuruti
# Processing Record 3 of Set 11 | muli
# Processing Record 4 of Set 11 | puerto ayacucho
# Processing Record 5 of Set 11 | broome
# Processing Record 6 of Set 11 | halalo
# City not found. Skipping...
# Processing Record 7 of Set 11 | tabuk
# Processing Record 8 of Set 11 | castle rock
# Processing Record 9 of Set 11 | tim
# Processing Record 10 of Set 11 | malindi
# Processing Record 11 of Set 11 | namibe
# Processing Record 12 of Set 11 | mulanje
# Processing Record 13 of Set 11 | ayr
# Processing Record 14 of Set 11 | merauke
# Processing Record 15 of Set 11 | hay river
# Processing Record 16 of Set 11 | zalantun
# Processing Record 17 of Set 11 | mount pleasant
# Processing Record 18 of Set 11 | olafsvik
# Processing Record 19 of Set 11 | jiuquan
# Processing Record 20 of Set 11 | yazman
# Processing Record 21 of Set 11 | grootfontein
# Processing Record 22 of Set 11 | eggenfelden
# Processing Record 23 of Set 11 | novita
# Processing Record 24 of Set 11 | noumea
# Processing Record 25 of Set 11 | chernyshevskiy
# Processing Record 26 of Set 11 | atlantis
# Processing Record 27 of Set 11 | birin
# Processing Record 28 of Set 11 | moosomin
# Processing Record 29 of Set 11 | kolokani
# Processing Record 30 of Set 11 | aborlan
# Processing Record 31 of Set 11 | isabela
# Processing Record 32 of Set 11 | kosa
# Processing Record 33 of Set 11 | half moon bay
# Processing Record 34 of Set 11 | kharan
# Processing Record 35 of Set 11 | santa maria
# Processing Record 36 of Set 11 | omboue
# Processing Record 37 of Set 11 | krasnoarmeysk
# Processing Record 38 of Set 11 | sentyabrskiy
# City not found. Skipping...
# Processing Record 39 of Set 11 | morondava
# Processing Record 40 of Set 11 | robe
# Processing Record 41 of Set 11 | kremenchuk
# Processing Record 42 of Set 11 | xining
# Processing Record 43 of Set 11 | magadan
# Processing Record 44 of Set 11 | nushki
# Processing Record 45 of Set 11 | talcahuano
# Processing Record 46 of Set 11 | kincardine
# Processing Record 47 of Set 11 | puerto carreno
# Processing Record 48 of Set 11 | ondorhaan
# City not found. Skipping...
# Processing Record 49 of Set 11 | dingle
# Processing Record 50 of Set 11 | praia da vitoria
# Processing Record 1 of Set 12 | yulara
# Processing Record 2 of Set 12 | pangody
# Processing Record 3 of Set 12 | umm lajj
# Processing Record 4 of Set 12 | ilheus
# Processing Record 5 of Set 12 | krasnoselkup
# Processing Record 6 of Set 12 | vitim
# Processing Record 7 of Set 12 | ixtapa
# Processing Record 8 of Set 12 | alizai
# Processing Record 9 of Set 12 | constitucion
# Processing Record 10 of Set 12 | sakhon nakhon
# Processing Record 11 of Set 12 | kroya
# Processing Record 12 of Set 12 | tabuny
# Processing Record 13 of Set 12 | sao jose da coroa grande
# Processing Record 14 of Set 12 | aporawan
# City not found. Skipping...
# Processing Record 15 of Set 12 | geresk
# City not found. Skipping...
# Processing Record 16 of Set 12 | anadyr
# Processing Record 17 of Set 12 | ouadda
# Processing Record 18 of Set 12 | nacogdoches
# Processing Record 19 of Set 12 | klyuchi
# Processing Record 20 of Set 12 | zubtsov
# Processing Record 21 of Set 12 | mordovo
# Processing Record 22 of Set 12 | anage
# Processing Record 23 of Set 12 | wanning
# Processing Record 24 of Set 12 | charcas
# Processing Record 25 of Set 12 | lucenec
# Processing Record 26 of Set 12 | banjar
# Processing Record 27 of Set 12 | bontang
# Processing Record 28 of Set 12 | uyuni
# Processing Record 29 of Set 12 | san rafael
# Processing Record 30 of Set 12 | nizwa
# Processing Record 31 of Set 12 | pacifica
# Processing Record 32 of Set 12 | bereda
# Processing Record 33 of Set 12 | coihaique
# Processing Record 34 of Set 12 | tobermory
# Processing Record 35 of Set 12 | gisborne
# Processing Record 36 of Set 12 | drjanovo
# City not found. Skipping...
# Processing Record 37 of Set 12 | cayenne
# Processing Record 38 of Set 12 | machiques
# Processing Record 39 of Set 12 | nadym
# Processing Record 40 of Set 12 | ipixuna
# Processing Record 41 of Set 12 | piacabucu
# Processing Record 42 of Set 12 | baghdad
# Processing Record 43 of Set 12 | carros
# Processing Record 44 of Set 12 | wyndham
# Processing Record 45 of Set 12 | chapais
# Processing Record 46 of Set 12 | itacarambi
# Processing Record 47 of Set 12 | nabire
# Processing Record 48 of Set 12 | alghero
# Processing Record 49 of Set 12 | barranca
# Processing Record 50 of Set 12 | sibolga
# Processing Record 1 of Set 13 | novopokrovka
# Processing Record 2 of Set 13 | bitung
# Processing Record 3 of Set 13 | itarema
# Processing Record 4 of Set 13 | pativilca
# Processing Record 5 of Set 13 | thyolo
# Processing Record 6 of Set 13 | roma
# Processing Record 7 of Set 13 | hargeysa
# Processing Record 8 of Set 13 | kargil
# Processing Record 9 of Set 13 | webuye
# Processing Record 10 of Set 13 | orangeburg
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Lorengau  -2.0226  147.2712     80.80        80         100
# 1  Punta Arenas -53.1500  -70.9167     50.00        57           0
# 2      Cururupu  -1.8283  -44.8683     76.57        88          49
# 3   New Norfolk -42.7826  147.0587     75.99        83          75
# 4        Albany  42.6001  -73.9662     32.00        59          20
# 5          Lebu -37.6167  -73.6500     61.68        78           0
# 6      Cherskiy  68.7500  161.3000     -9.00        75          95
# 7     Ilulissat  69.2167  -51.1000      1.40        39           0
# 8  Norman Wells  65.2820 -126.8329    -40.00        67          40
# 9          Lasa  46.6166   10.7002     39.00        86           0
#
#    Wind Speed Country                 Date
# 0        6.96      PG  2021-02-05 00:33:02
# 1       25.32      CL  2021-02-05 00:30:55
# 2        4.14      BR  2021-02-05 00:34:09
# 3        6.91      AU  2021-02-05 00:32:01
# 4        4.74      US  2021-02-05 00:29:21
# 5        1.03      CL  2021-02-05 00:32:30
# 6       10.63      RU  2021-02-05 00:32:34
# 7       13.80      GL  2021-02-05 00:29:08
# 8        2.30      CA  2021-02-05 00:32:41
# 9        6.91      IT  2021-02-05 00:32:43

# %%
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]

city_data_df = city_data_df[new_column_order]

city_data_df
# Out:
#              City Country                 Date      Lat       Lng  Max Temp  \
# 0        Lorengau      PG  2021-02-05 00:33:02  -2.0226  147.2712     80.80
# 1    Punta Arenas      CL  2021-02-05 00:30:55 -53.1500  -70.9167     50.00
# 2        Cururupu      BR  2021-02-05 00:34:09  -1.8283  -44.8683     76.57
# 3     New Norfolk      AU  2021-02-05 00:32:01 -42.7826  147.0587     75.99
# 4          Albany      US  2021-02-05 00:29:21  42.6001  -73.9662     32.00
# ..            ...     ...                  ...      ...       ...       ...
# 557          Roma      US  2021-02-05 00:32:35  43.2128  -75.4557     24.80
# 558      Hargeysa      SO  2021-02-05 00:35:49   9.5600   44.0650     52.95
# 559        Kargil      IN  2021-02-05 00:35:49  34.5667   76.1000     -6.97
# 560        Webuye      KE  2021-02-05 00:35:49   0.6075   34.7697     59.00
# 561    Orangeburg      US  2021-02-05 00:35:49  33.4918  -80.8557     50.00
#
#      Humidity  Cloudiness  Wind Speed
# 0          80         100        6.96
# 1          57           0       25.32
# 2          88          49        4.14
# 3          83          75        6.91
# 4          59          20        4.74
# ..        ...         ...         ...
# 557        74           1        3.44
# 558        73           0        2.39
# 559        73          71        1.97
# 560        88           0        3.44
# 561        50           1        5.75
#
# [562 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
# Extract relevant fields from the DataFrame for plotting.
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %%
# Import time module
import time

# Build the scatter plot for latitude vs. max temperature.
plt.scatter(lats,
            max_temps,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Max Temperature "+ time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig1.png")

# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. humidity.
plt.scatter(lats,
            humidity,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig2.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. cloudiness.
plt.scatter(lats,
            cloudiness,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Cloudiness (%) "+ time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig3.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. wind speed.
plt.scatter(lats,
            wind_speed,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Wind Speed "+ time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig4.png")
# Show plot.
plt.show()

# %%
# Import linregress
from scipy.stats import linregress

# Create a function to create perform linear regression on the weather data
# and plot a regression line and the equation with the data.
def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):

    # Run regression on hemisphere weather data.
    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)

    # Calculate the regression line "y values" from the slope and intercept.
    regress_values = x_values * slope + intercept
    # Get the equation of the line.
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    # Create a scatter plot and plot the regression line.
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r")
    # Annotate the text for the line equation.
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
    plt.xlabel('Latitude')
    plt.ylabel(y_label)
    plt.show()

# %%
index13 = city_data_df.loc[13]
index13
# Out:
# City                      Mataura
# Country                        NZ
# Date          2021-02-05 00:28:19
# Lat                      -46.1927
# Lng                       168.864
# Max Temp                    68.94
# Humidity                       47
# Cloudiness                     51
# Wind Speed                   3.42
# Name: 13, dtype: object

# %%
city_data_df["Lat"] >= 0
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 557     True
# 558     True
# 559     True
# 560     True
# 561     True
# Name: Lat, Length: 562, dtype: bool

# %%
city_data_df.loc[(city_data_df["Lat"] >= 0)].head()
# Out:
#            City Country                 Date      Lat       Lng  Max Temp  \
# 4        Albany      US  2021-02-05 00:29:21  42.6001  -73.9662      32.0
# 6      Cherskiy      RU  2021-02-05 00:32:34  68.7500  161.3000      -9.0
# 7     Ilulissat      GL  2021-02-05 00:29:08  69.2167  -51.1000       1.4
# 8  Norman Wells      CA  2021-02-05 00:32:41  65.2820 -126.8329     -40.0
# 9          Lasa      IT  2021-02-05 00:32:43  46.6166   10.7002      39.0
#
#    Humidity  Cloudiness  Wind Speed
# 4        59          20        4.74
# 6        75          95       10.63
# 7        39           0       13.80
# 8        67          40        2.30
# 9        86           0        6.91

# %%
# Create Northern and Southern Hemisphere DataFrames.
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] < 0)]

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for Maximum Temperature', 'Max Temp',(0,0))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for Maximum Temperature', 'Max Temp',(-50,55))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for % Humidity', '% Humidity',(40,20))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for % Humidity', '% Humidity',(-50,15))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for % Cloudiness', '% Cloudiness',(40,20))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \n'
                        'for % Cloudiness', '% Cloudiness',(-50,60))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \n'
                        'for Wind Speed', 'Wind Speed',(40,30))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \n'
                        'for Wind Speed', 'Wind Speed',(-50,30))

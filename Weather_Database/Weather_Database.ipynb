# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 740

# %%
# Import the requests library.
import requests

# Import the API key.
from config2 import weather_api_key

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
       
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Date": city_date,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_description,
                          "Country": city_country})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 41 of Set 57 | yellowknife
# Processing Record 42 of Set 57 | longyearbyen
# Processing Record 43 of Set 57 | upernavik
# Processing Record 44 of Set 57 | havelock
# Processing Record 45 of Set 57 | manthani
# Processing Record 46 of Set 57 | beringovskiy
# Processing Record 47 of Set 57 | jamestown
# Processing Record 48 of Set 57 | castro
# Processing Record 49 of Set 57 | husavik
# Processing Record 50 of Set 57 | nikolskoye
# Processing Record 51 of Set 57 | ushuaia
# Processing Record 52 of Set 57 | leningradskiy
# Processing Record 53 of Set 57 | victoria
# Processing Record 54 of Set 57 | inuvik
# Processing Record 55 of Set 57 | east london
# Processing Record 56 of Set 57 | alofi
# Processing Record 57 of Set 57 | busselton
# Processing Record 58 of Set 57 | scarborough
# Processing Record 59 of Set 57 | rikitea
# Processing Record 60 of Set 57 | georgetown
# Processing Record 61 of Set 57 | tuktoyaktuk
# Processing Record 62 of Set 57 | warmbad
# Processing Record 63 of Set 57 | codrington
# Processing Record 64 of Set 57 | port hardy
# Processing Record 65 of Set 57 | tucuma
# Processing Record 66 of Set 57 | russell
# Processing Record 67 of Set 57 | tiksi
# Processing Record 68 of Set 57 | nidzica
# Processing Record 69 of Set 57 | tasiilaq
# Processing Record 70 of Set 57 | bejar
# Processing Record 71 of Set 57 | dhidhdhoo
# Processing Record 72 of Set 57 | vaitape
# Processing Record 73 of Set 57 | barrow
# Processing Record 74 of Set 57 | mataura
# Processing Record 75 of Set 57 | taolanaro
# City not found. Skipping...
# Processing Record 76 of Set 57 | kapaa
# Processing Record 77 of Set 57 | albany
# Processing Record 78 of Set 57 | barra dos coqueiros
# Processing Record 79 of Set 57 | pimentel
# Processing Record 80 of Set 57 | te anau
# Processing Record 81 of Set 57 | port keats
# Processing Record 82 of Set 57 | anloga
# Processing Record 83 of Set 57 | bur gabo
# City not found. Skipping...
# Processing Record 84 of Set 57 | pozo colorado
# Processing Record 85 of Set 57 | arraial do cabo
# Processing Record 86 of Set 57 | port elizabeth
# Processing Record 87 of Set 57 | aklavik
# Processing Record 88 of Set 57 | hami
# Processing Record 89 of Set 57 | bredasdorp
# Processing Record 90 of Set 57 | mount isa
# Processing Record 1 of Set 58 | sharjah
# Processing Record 2 of Set 58 | hobart
# Processing Record 3 of Set 58 | morros
# Processing Record 4 of Set 58 | kroya
# Processing Record 5 of Set 58 | atuona
# Processing Record 6 of Set 58 | cartagena
# Processing Record 7 of Set 58 | roma
# Processing Record 8 of Set 58 | thompson
# Processing Record 9 of Set 58 | ruatoria
# City not found. Skipping...
# Processing Record 10 of Set 58 | severo-kurilsk
# Processing Record 11 of Set 58 | trinidad
# Processing Record 12 of Set 58 | tommot
# Processing Record 13 of Set 58 | terneuzen
# Processing Record 14 of Set 58 | butembo
# Processing Record 15 of Set 58 | saint-philippe
# Processing Record 16 of Set 58 | olafsvik
# Processing Record 17 of Set 58 | inirida
# Processing Record 18 of Set 58 | cockburn harbour
# City not found. Skipping...
# Processing Record 19 of Set 58 | punta arenas
# Processing Record 20 of Set 58 | la ronge
# Processing Record 21 of Set 58 | ilulissat
# Processing Record 22 of Set 58 | cidreira
# Processing Record 23 of Set 58 | atambua
# Processing Record 24 of Set 58 | vestbygda
# City not found. Skipping...
# Processing Record 25 of Set 58 | hilo
# Processing Record 26 of Set 58 | puerto ayora
# Processing Record 27 of Set 58 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 28 of Set 58 | vaini
# Processing Record 29 of Set 58 | sentyabrskiy
# City not found. Skipping...
# Processing Record 30 of Set 58 | shumskiy
# Processing Record 31 of Set 58 | chuy
# Processing Record 32 of Set 58 | butaritari
# Processing Record 33 of Set 58 | yerbogachen
# Processing Record 34 of Set 58 | boca do acre
# Processing Record 35 of Set 58 | pascagoula
# Processing Record 36 of Set 58 | acapulco
# Processing Record 37 of Set 58 | provideniya
# Processing Record 38 of Set 58 | ust-ilimsk
# Processing Record 39 of Set 58 | port alfred
# Processing Record 40 of Set 58 | bluff
# Processing Record 41 of Set 58 | thinadhoo
# Processing Record 42 of Set 58 | morondava
# Processing Record 43 of Set 58 | boende
# Processing Record 44 of Set 58 | hithadhoo
# Processing Record 45 of Set 58 | berlevag
# Processing Record 46 of Set 58 | iqaluit
# Processing Record 47 of Set 58 | karratha
# Processing Record 48 of Set 58 | hermanus
# Processing Record 49 of Set 58 | mehamn
# Processing Record 50 of Set 58 | basco
# Processing Record 1 of Set 59 | erenhot
# Processing Record 2 of Set 59 | cabo san lucas
# Processing Record 3 of Set 59 | bambous virieux
# Processing Record 4 of Set 59 | chokurdakh
# Processing Record 5 of Set 59 | hambantota
# Processing Record 6 of Set 59 | kiruna
# Processing Record 7 of Set 59 | mar del plata
# Processing Record 8 of Set 59 | bismarck
# Processing Record 9 of Set 59 | khilok
# Processing Record 10 of Set 59 | bosaso
# Processing Record 11 of Set 59 | faanui
# Processing Record 12 of Set 59 | mrirt
# City not found. Skipping...
# Processing Record 13 of Set 59 | san isidro
# Processing Record 14 of Set 59 | rudbar
# Processing Record 15 of Set 59 | kaeo
# Processing Record 16 of Set 59 | rebrikha
# Processing Record 17 of Set 59 | nanortalik
# Processing Record 18 of Set 59 | namibe
# Processing Record 19 of Set 59 | yatou
# Processing Record 20 of Set 59 | arlit
# Processing Record 21 of Set 59 | khatanga
# Processing Record 22 of Set 59 | nizwa
# Processing Record 23 of Set 59 | tsihombe
# City not found. Skipping...
# Processing Record 24 of Set 59 | samalaeulu
# City not found. Skipping...
# Processing Record 25 of Set 59 | guerrero negro
# Processing Record 26 of Set 59 | kamenka
# Processing Record 27 of Set 59 | kodiak
# Processing Record 28 of Set 59 | kaspiyskiy
# Processing Record 29 of Set 59 | egvekinot
# Processing Record 30 of Set 59 | new norfolk
# Processing Record 31 of Set 59 | san pedro
# Processing Record 32 of Set 59 | sao filipe
# Processing Record 33 of Set 59 | barentsburg
# City not found. Skipping...
# Processing Record 34 of Set 59 | saint-michel-des-saints
# Processing Record 35 of Set 59 | avera
# Processing Record 36 of Set 59 | brae
# Processing Record 37 of Set 59 | ordzhonikidze
# Processing Record 38 of Set 59 | broken hill
# Processing Record 39 of Set 59 | ucluelet
# Processing Record 40 of Set 59 | torbay
# Processing Record 41 of Set 59 | japura
# Processing Record 42 of Set 59 | mitsamiouli
# Processing Record 43 of Set 59 | norman wells
# Processing Record 44 of Set 59 | attawapiskat
# City not found. Skipping...
# Processing Record 45 of Set 59 | kismayo
# Processing Record 46 of Set 59 | atar
# Processing Record 47 of Set 59 | santa maria da vitoria
# Processing Record 48 of Set 59 | lebu
# Processing Record 49 of Set 59 | amurzet
# Processing Record 50 of Set 59 | gardez
# Processing Record 1 of Set 60 | pisco
# Processing Record 2 of Set 60 | kaitangata
# Processing Record 3 of Set 60 | komsomolskiy
# Processing Record 4 of Set 60 | makakilo city
# Processing Record 5 of Set 60 | clyde river
# Processing Record 6 of Set 60 | dikson
# Processing Record 7 of Set 60 | mys shmidta
# City not found. Skipping...
# Processing Record 8 of Set 60 | kahului
# Processing Record 9 of Set 60 | avarua
# Processing Record 10 of Set 60 | do gonbadan
# Processing Record 11 of Set 60 | poum
# Processing Record 12 of Set 60 | maloy
# Processing Record 13 of Set 60 | saint george
# Processing Record 14 of Set 60 | boyolangu
# Processing Record 15 of Set 60 | ponta do sol
# Processing Record 16 of Set 60 | bengkulu
# Processing Record 17 of Set 60 | lompoc
# Processing Record 18 of Set 60 | tigil
# Processing Record 19 of Set 60 | saleaula
# City not found. Skipping...
# Processing Record 20 of Set 60 | halifax
# Processing Record 21 of Set 60 | mnogovershinnyy
# Processing Record 22 of Set 60 | half moon bay
# Processing Record 23 of Set 60 | kargasok
# Processing Record 24 of Set 60 | ust-kuyga
# Processing Record 25 of Set 60 | chernyshevskiy
# Processing Record 26 of Set 60 | jurmala
# Processing Record 27 of Set 60 | monster
# Processing Record 28 of Set 60 | tilichiki
# Processing Record 29 of Set 60 | kortkeros
# Processing Record 30 of Set 60 | matane
# Processing Record 31 of Set 60 | amderma
# City not found. Skipping...
# Processing Record 32 of Set 60 | srednekolymsk
# Processing Record 33 of Set 60 | cape town
# Processing Record 34 of Set 60 | ribeira grande
# Processing Record 35 of Set 60 | beira
# Processing Record 36 of Set 60 | carbonear
# Processing Record 37 of Set 60 | lima
# Processing Record 38 of Set 60 | yumen
# Processing Record 39 of Set 60 | hanstholm
# Processing Record 40 of Set 60 | airai
# Processing Record 41 of Set 60 | saldanha
# Processing Record 42 of Set 60 | sisimiut
# Processing Record 43 of Set 60 | kieta
# Processing Record 44 of Set 60 | kiunga
# Processing Record 45 of Set 60 | beloha
# Processing Record 46 of Set 60 | pevek
# Processing Record 47 of Set 60 | nizhneyansk
# City not found. Skipping...
# Processing Record 48 of Set 60 | isangel
# Processing Record 49 of Set 60 | antropovo
# Processing Record 50 of Set 60 | vanavara
# Processing Record 1 of Set 61 | ljungby
# Processing Record 2 of Set 61 | faya
# Processing Record 3 of Set 61 | padre bernardo
# Processing Record 4 of Set 61 | grand river south east
# City not found. Skipping...
# Processing Record 5 of Set 61 | saskylakh
# Processing Record 6 of Set 61 | talnakh
# Processing Record 7 of Set 61 | damara
# Processing Record 8 of Set 61 | plettenberg bay
# Processing Record 9 of Set 61 | lavrentiya
# Processing Record 10 of Set 61 | gornopravdinsk
# Processing Record 11 of Set 61 | talara
# Processing Record 12 of Set 61 | tawkar
# City not found. Skipping...
# Processing Record 13 of Set 61 | kudahuvadhoo
# Processing Record 14 of Set 61 | port-gentil
# Processing Record 15 of Set 61 | porto velho
# Processing Record 16 of Set 61 | sungairaya
# Processing Record 17 of Set 61 | sherwood
# Processing Record 18 of Set 61 | beinamar
# Processing Record 19 of Set 61 | chapais
# Processing Record 20 of Set 61 | pangnirtung
# Processing Record 21 of Set 61 | mut
# Processing Record 22 of Set 61 | zhumadian
# Processing Record 23 of Set 61 | blonduos
# City not found. Skipping...
# Processing Record 24 of Set 61 | sarkand
# Processing Record 25 of Set 61 | san quintin
# Processing Record 26 of Set 61 | bonavista
# Processing Record 27 of Set 61 | mandera
# Processing Record 28 of Set 61 | ketchikan
# Processing Record 29 of Set 61 | umzimvubu
# City not found. Skipping...
# Processing Record 30 of Set 61 | patacamaya
# Processing Record 31 of Set 61 | ancud
# Processing Record 32 of Set 61 | saint-joseph
# Processing Record 33 of Set 61 | gerash
# Processing Record 34 of Set 61 | killybegs
# Processing Record 35 of Set 61 | westport
# Processing Record 36 of Set 61 | anadyr
# Processing Record 37 of Set 61 | los llanos de aridane
# Processing Record 38 of Set 61 | caravelas
# Processing Record 39 of Set 61 | san patricio
# Processing Record 40 of Set 61 | katsuura
# Processing Record 41 of Set 61 | marienburg
# Processing Record 42 of Set 61 | khasan
# Processing Record 43 of Set 61 | tumannyy
# City not found. Skipping...
# Processing Record 44 of Set 61 | lagoa
# Processing Record 45 of Set 61 | changji
# Processing Record 46 of Set 61 | shelburne
# Processing Record 47 of Set 61 | saint-pierre
# Processing Record 48 of Set 61 | carnarvon
# Processing Record 49 of Set 61 | sorland
# Processing Record 50 of Set 61 | jacmel
# Processing Record 1 of Set 62 | camacupa
# Processing Record 2 of Set 62 | mosquera
# Processing Record 3 of Set 62 | progreso
# Processing Record 4 of Set 62 | kamaishi
# Processing Record 5 of Set 62 | trelleborg
# Processing Record 6 of Set 62 | kabompo
# Processing Record 7 of Set 62 | malwan
# City not found. Skipping...
# Processing Record 8 of Set 62 | brandfort
# Processing Record 9 of Set 62 | kavieng
# Processing Record 10 of Set 62 | belushya guba
# City not found. Skipping...
# Processing Record 11 of Set 62 | guayaramerin
# Processing Record 12 of Set 62 | ulcinj
# Processing Record 13 of Set 62 | rozkishne
# Processing Record 14 of Set 62 | lingyuan
# Processing Record 15 of Set 62 | port pirie
# Processing Record 16 of Set 62 | grindavik
# Processing Record 17 of Set 62 | lorengau
# Processing Record 18 of Set 62 | dergachi
# Processing Record 19 of Set 62 | izhmorskiy
# Processing Record 20 of Set 62 | hofn
# Processing Record 21 of Set 62 | kabanjahe
# Processing Record 22 of Set 62 | stilfontein
# Processing Record 23 of Set 62 | vacaria
# Processing Record 24 of Set 62 | gravdal
# Processing Record 25 of Set 62 | esperance
# Processing Record 26 of Set 62 | inyonga
# Processing Record 27 of Set 62 | tuatapere
# Processing Record 28 of Set 62 | san cristobal
# Processing Record 29 of Set 62 | the valley
# Processing Record 30 of Set 62 | goderich
# Processing Record 31 of Set 62 | dunedin
# Processing Record 32 of Set 62 | mount gambier
# Processing Record 33 of Set 62 | sept-iles
# Processing Record 34 of Set 62 | hot springs
# Processing Record 35 of Set 62 | mahebourg
# Processing Record 36 of Set 62 | diebougou
# Processing Record 37 of Set 62 | sikonge
# Processing Record 38 of Set 62 | ilhabela
# Processing Record 39 of Set 62 | moyobamba
# Processing Record 40 of Set 62 | suksun
# Processing Record 41 of Set 62 | pontalina
# Processing Record 42 of Set 62 | urucara
# Processing Record 43 of Set 62 | perigueux
# Processing Record 44 of Set 62 | cayenne
# Processing Record 45 of Set 62 | luderitz
# Processing Record 46 of Set 62 | debar
# Processing Record 47 of Set 62 | broome
# Processing Record 48 of Set 62 | uchiza
# Processing Record 49 of Set 62 | lasa
# Processing Record 50 of Set 62 | lomza
# Processing Record 1 of Set 63 | sampit
# Processing Record 2 of Set 63 | padra
# Processing Record 3 of Set 63 | geraldton
# Processing Record 4 of Set 63 | mpika
# Processing Record 5 of Set 63 | zholymbet
# Processing Record 6 of Set 63 | kingman
# Processing Record 7 of Set 63 | balikpapan
# Processing Record 8 of Set 63 | cam ranh
# Processing Record 9 of Set 63 | chicama
# Processing Record 10 of Set 63 | motala
# Processing Record 11 of Set 63 | antofagasta
# Processing Record 12 of Set 63 | qaanaaq
# Processing Record 13 of Set 63 | alirajpur
# Processing Record 14 of Set 63 | namatanai
# Processing Record 15 of Set 63 | pangoa
# Processing Record 16 of Set 63 | adrar
# Processing Record 17 of Set 63 | razole
# Processing Record 18 of Set 63 | birao
# Processing Record 19 of Set 63 | singaraja
# Processing Record 20 of Set 63 | gamba
# Processing Record 21 of Set 63 | iberia
# Processing Record 22 of Set 63 | porto nacional
# Processing Record 23 of Set 63 | edson
# Processing Record 24 of Set 63 | kemijarvi
# Processing Record 25 of Set 63 | rawson
# Processing Record 26 of Set 63 | rincon
# Processing Record 27 of Set 63 | klaksvik
# Processing Record 28 of Set 63 | staryy nadym
# Processing Record 29 of Set 63 | vreed en hoop
# City not found. Skipping...
# Processing Record 30 of Set 63 | inhambane
# Processing Record 31 of Set 63 | ahipara
# Processing Record 32 of Set 63 | tinskoy
# Processing Record 33 of Set 63 | sobolevo
# Processing Record 34 of Set 63 | khandyga
# Processing Record 35 of Set 63 | inderborskiy
# City not found. Skipping...
# Processing Record 36 of Set 63 | dingle
# Processing Record 37 of Set 63 | seoul
# Processing Record 38 of Set 63 | mumbwa
# Processing Record 39 of Set 63 | tottori
# Processing Record 40 of Set 63 | palabuhanratu
# City not found. Skipping...
# Processing Record 41 of Set 63 | yuzhnouralsk
# Processing Record 42 of Set 63 | lac du bonnet
# Processing Record 43 of Set 63 | tabou
# Processing Record 44 of Set 63 | ternate
# Processing Record 45 of Set 63 | maceio
# Processing Record 46 of Set 63 | henties bay
# Processing Record 47 of Set 63 | ca mau
# Processing Record 48 of Set 63 | vama buzaului
# City not found. Skipping...
# Processing Record 49 of Set 63 | naze
# Processing Record 50 of Set 63 | bethel
# Processing Record 1 of Set 64 | tashara
# Processing Record 2 of Set 64 | sattahip
# Processing Record 3 of Set 64 | filadelfia
# Processing Record 4 of Set 64 | taltal
# Processing Record 5 of Set 64 | tecpan
# Processing Record 6 of Set 64 | samarai
# Processing Record 7 of Set 64 | traralgon
# Processing Record 8 of Set 64 | brigantine
# Processing Record 9 of Set 64 | college
# Processing Record 10 of Set 64 | shaunavon
# Processing Record 11 of Set 64 | ossora
# Processing Record 12 of Set 64 | alcaniz
# Processing Record 13 of Set 64 | pacific grove
# Processing Record 14 of Set 64 | racale
# Processing Record 15 of Set 64 | bondo
# Processing Record 16 of Set 64 | narsaq
# Processing Record 17 of Set 64 | igrim
# Processing Record 18 of Set 64 | desaguadero
# Processing Record 19 of Set 64 | myitkyina
# Processing Record 20 of Set 64 | miyako
# Processing Record 21 of Set 64 | balaipungut
# Processing Record 22 of Set 64 | homer
# Processing Record 23 of Set 64 | okato
# Processing Record 24 of Set 64 | contai
# Processing Record 25 of Set 64 | bodden town
# Processing Record 26 of Set 64 | aksarka
# Processing Record 27 of Set 64 | martil
# Processing Record 28 of Set 64 | tarudant
# City not found. Skipping...
# Processing Record 29 of Set 64 | moose factory
# Processing Record 30 of Set 64 | wesselsbron
# Processing Record 31 of Set 64 | bloemfontein
# Processing Record 32 of Set 64 | muros
# Processing Record 33 of Set 64 | tezu
# Processing Record 34 of Set 64 | wanaka
# Processing Record 35 of Set 64 | marzuq
# Processing Record 36 of Set 64 | bardiyah
# Processing Record 37 of Set 64 | barawe
# City not found. Skipping...
# Processing Record 38 of Set 64 | isla vista
# Processing Record 39 of Set 64 | comodoro rivadavia
# Processing Record 40 of Set 64 | coelho neto
# Processing Record 41 of Set 64 | viligili
# City not found. Skipping...
# Processing Record 42 of Set 64 | kochubey
# Processing Record 43 of Set 64 | aykhal
# Processing Record 44 of Set 64 | weleri
# Processing Record 45 of Set 64 | gat
# Processing Record 46 of Set 64 | salalah
# Processing Record 47 of Set 64 | touros
# Processing Record 48 of Set 64 | pangody
# Processing Record 49 of Set 64 | qianjiang
# Processing Record 50 of Set 64 | burnie
# Processing Record 1 of Set 65 | ao luk
# City not found. Skipping...
# Processing Record 2 of Set 65 | richards bay
# Processing Record 3 of Set 65 | rassvet
# Processing Record 4 of Set 65 | maragogi
# Processing Record 5 of Set 65 | kenai
# Processing Record 6 of Set 65 | nome
# Processing Record 7 of Set 65 | mizan teferi
# Processing Record 8 of Set 65 | maues
# Processing Record 9 of Set 65 | ambodifototra
# City not found. Skipping...
# Processing Record 10 of Set 65 | tomatlan
# Processing Record 11 of Set 65 | acajutla
# Processing Record 12 of Set 65 | port blair
# Processing Record 13 of Set 65 | itarema
# Processing Record 14 of Set 65 | martapura
# Processing Record 15 of Set 65 | flinders
# Processing Record 16 of Set 65 | chara
# Processing Record 17 of Set 65 | fortuna
# Processing Record 18 of Set 65 | mugur-aksy
# Processing Record 19 of Set 65 | ihiala
# Processing Record 20 of Set 65 | issaquah
# Processing Record 21 of Set 65 | marcona
# City not found. Skipping...
# Processing Record 22 of Set 65 | karamea
# City not found. Skipping...
# Processing Record 23 of Set 65 | cherskiy
# Processing Record 24 of Set 65 | sandy bay
# Processing Record 25 of Set 65 | laguna
# Processing Record 26 of Set 65 | lolua
# City not found. Skipping...
# Processing Record 27 of Set 65 | san juan
# Processing Record 28 of Set 65 | rena
# Processing Record 29 of Set 65 | port macquarie
# Processing Record 30 of Set 65 | inongo
# Processing Record 31 of Set 65 | chapayeve
# Processing Record 32 of Set 65 | fairbanks
# Processing Record 33 of Set 65 | deputatskiy
# Processing Record 34 of Set 65 | rocha
# Processing Record 35 of Set 65 | uray
# Processing Record 36 of Set 65 | galesong
# Processing Record 37 of Set 65 | oistins
# Processing Record 38 of Set 65 | batagay-alyta
# Processing Record 39 of Set 65 | grajau
# Processing Record 40 of Set 65 | yomitan
# City not found. Skipping...
# Processing Record 41 of Set 65 | kruisfontein
# Processing Record 42 of Set 65 | shibarghan
# City not found. Skipping...
# Processing Record 43 of Set 65 | san felipe
# Processing Record 44 of Set 65 | tidore
# City not found. Skipping...
# Processing Record 45 of Set 65 | upata
# Processing Record 46 of Set 65 | sibolga
# Processing Record 47 of Set 65 | kropotkin
# Processing Record 48 of Set 65 | batemans bay
# Processing Record 49 of Set 65 | green river
# Processing Record 50 of Set 65 | gurlan
# Processing Record 1 of Set 66 | dunmore town
# Processing Record 2 of Set 66 | new glasgow
# Processing Record 3 of Set 66 | huntsville
# Processing Record 4 of Set 66 | furstenfeldbruck
# City not found. Skipping...
# Processing Record 5 of Set 66 | mangrol
# Processing Record 6 of Set 66 | kingaroy
# Processing Record 7 of Set 66 | nelson bay
# Processing Record 8 of Set 66 | marsaxlokk
# Processing Record 9 of Set 66 | svetlaya
# Processing Record 10 of Set 66 | bratsk
# Processing Record 11 of Set 66 | mogadishu
# Processing Record 12 of Set 66 | baherden
# Processing Record 13 of Set 66 | seddon
# Processing Record 14 of Set 66 | bababe
# City not found. Skipping...
# Processing Record 15 of Set 66 | jalu
# Processing Record 16 of Set 66 | whitehorse
# Processing Record 17 of Set 66 | macenta
# Processing Record 18 of Set 66 | aberdeen
# Processing Record 19 of Set 66 | mergui
# City not found. Skipping...
# Processing Record 20 of Set 66 | sibi
# Processing Record 21 of Set 66 | taft
# Processing Record 22 of Set 66 | mana
# Processing Record 23 of Set 66 | candido mendes
# Processing Record 24 of Set 66 | taburi
# City not found. Skipping...
# Processing Record 25 of Set 66 | stornoway
# Processing Record 26 of Set 66 | nombre de dios
# Processing Record 27 of Set 66 | yhu
# Processing Record 28 of Set 66 | bitung
# Processing Record 29 of Set 66 | mbaiki
# Processing Record 30 of Set 66 | viedma
# Processing Record 31 of Set 66 | port lincoln
# Processing Record 32 of Set 66 | tutzing
# Processing Record 33 of Set 66 | battle creek
# Processing Record 34 of Set 66 | dzerzhinsk
# Processing Record 35 of Set 66 | dubbo
# Processing Record 36 of Set 66 | hualmay
# Processing Record 37 of Set 66 | denpasar
# Processing Record 38 of Set 66 | sao joao da barra
# Processing Record 39 of Set 66 | san luis
# Processing Record 40 of Set 66 | portland
# Processing Record 41 of Set 66 | outjo
# Processing Record 42 of Set 66 | ilinsko-podomskoye
# City not found. Skipping...
# Processing Record 43 of Set 66 | qasigiannguit
# Processing Record 44 of Set 66 | anahuac
# Processing Record 45 of Set 66 | farafangana
# Processing Record 46 of Set 66 | andevoranto
# City not found. Skipping...
# Processing Record 47 of Set 66 | la palma
# Processing Record 48 of Set 66 | vardo
# Processing Record 49 of Set 66 | andros town
# Processing Record 50 of Set 66 | cranbourne
# Processing Record 1 of Set 67 | wanning
# Processing Record 2 of Set 67 | jhang
# Processing Record 3 of Set 67 | honiara
# Processing Record 4 of Set 67 | sarangani
# Processing Record 5 of Set 67 | warqla
# City not found. Skipping...
# Processing Record 6 of Set 67 | tromso
# Processing Record 7 of Set 67 | golspie
# Processing Record 8 of Set 67 | svetlyy
# Processing Record 9 of Set 67 | peace river
# Processing Record 10 of Set 67 | kollam
# Processing Record 11 of Set 67 | champerico
# Processing Record 12 of Set 67 | khani
# Processing Record 13 of Set 67 | kisangani
# Processing Record 14 of Set 67 | nenjiang
# Processing Record 15 of Set 67 | coalcoman
# City not found. Skipping...
# Processing Record 16 of Set 67 | pirovskoye
# Processing Record 17 of Set 67 | krasnoselkup
# Processing Record 18 of Set 67 | veinticinco de mayo
# Processing Record 19 of Set 67 | wajima
# Processing Record 20 of Set 67 | souillac
# Processing Record 21 of Set 67 | buenos aires
# Processing Record 22 of Set 67 | nhulunbuy
# Processing Record 23 of Set 67 | abu dhabi
# Processing Record 24 of Set 67 | barcelos
# Processing Record 25 of Set 67 | umm kaddadah
# Processing Record 26 of Set 67 | goalpara
# Processing Record 27 of Set 67 | paamiut
# Processing Record 28 of Set 67 | bathsheba
# Processing Record 29 of Set 67 | magistralnyy
# Processing Record 30 of Set 67 | natal
# Processing Record 31 of Set 67 | maneadero
# Processing Record 32 of Set 67 | la paz
# Processing Record 33 of Set 67 | toppenish
# Processing Record 34 of Set 67 | garden city
# Processing Record 35 of Set 67 | vavuniya
# Processing Record 36 of Set 67 | strezhevoy
# Processing Record 37 of Set 67 | prince rupert
# Processing Record 38 of Set 67 | dunda
# Processing Record 39 of Set 67 | north myrtle beach
# Processing Record 40 of Set 67 | merauke
# Processing Record 41 of Set 67 | tskaltubo
# Processing Record 42 of Set 67 | axim
# Processing Record 43 of Set 67 | santa cruz del sur
# Processing Record 44 of Set 67 | diego de almagro
# Processing Record 45 of Set 67 | meulaboh
# Processing Record 46 of Set 67 | espita
# Processing Record 47 of Set 67 | olinda
# Processing Record 48 of Set 67 | samusu
# City not found. Skipping...
# Processing Record 49 of Set 67 | nara
# Processing Record 50 of Set 67 | santa vitoria
# Processing Record 1 of Set 68 | kyren
# Processing Record 2 of Set 68 | coolum beach
# Processing Record 3 of Set 68 | baykit
# Processing Record 4 of Set 68 | quatre cocos
# Processing Record 5 of Set 68 | canutama
# Processing Record 6 of Set 68 | nisia floresta
# Processing Record 7 of Set 68 | chagda
# City not found. Skipping...
# Processing Record 8 of Set 68 | lahaina
# Processing Record 9 of Set 68 | ogulin
# Processing Record 10 of Set 68 | kaduna
# Processing Record 11 of Set 68 | alice springs
# Processing Record 12 of Set 68 | cockburn town
# Processing Record 13 of Set 68 | port hedland
# Processing Record 14 of Set 68 | nantucket
# Processing Record 15 of Set 68 | manggar
# Processing Record 16 of Set 68 | turayf
# Processing Record 17 of Set 68 | marica
# Processing Record 18 of Set 68 | sinnamary
# Processing Record 19 of Set 68 | bogovarovo
# Processing Record 20 of Set 68 | kazerun
# Processing Record 21 of Set 68 | saraland
# Processing Record 22 of Set 68 | zhigansk
# Processing Record 23 of Set 68 | ostrovnoy
# Processing Record 24 of Set 68 | bunia
# Processing Record 25 of Set 68 | kirakira
# Processing Record 26 of Set 68 | pangai
# Processing Record 27 of Set 68 | marsh harbour
# Processing Record 28 of Set 68 | zheleznodorozhnyy
# Processing Record 29 of Set 68 | bilibino
# Processing Record 30 of Set 68 | sur
# Processing Record 31 of Set 68 | otorohanga
# Processing Record 32 of Set 68 | altay
# Processing Record 33 of Set 68 | vallenar
# Processing Record 34 of Set 68 | kysyl-syr
# Processing Record 35 of Set 68 | baghmara
# Processing Record 36 of Set 68 | sao felix do xingu
# Processing Record 37 of Set 68 | tuburan
# Processing Record 38 of Set 68 | xichang
# Processing Record 39 of Set 68 | hasaki
# Processing Record 40 of Set 68 | sola
# Processing Record 41 of Set 68 | xingyi
# Processing Record 42 of Set 68 | oliveira
# Processing Record 43 of Set 68 | show low
# Processing Record 44 of Set 68 | juneau
# Processing Record 45 of Set 68 | pegnitz
# Processing Record 46 of Set 68 | mushie
# Processing Record 47 of Set 68 | canon city
# Processing Record 48 of Set 68 | zhanaozen
# Processing Record 49 of Set 68 | karaton
# Processing Record 50 of Set 68 | esna
# Processing Record 1 of Set 69 | batagay
# Processing Record 2 of Set 69 | shitanjing
# Processing Record 3 of Set 69 | fort nelson
# Processing Record 4 of Set 69 | midland
# Processing Record 5 of Set 69 | ampanihy
# Processing Record 6 of Set 69 | haines junction
# Processing Record 7 of Set 69 | oriximina
# Processing Record 8 of Set 69 | sredniy ikorets
# Processing Record 9 of Set 69 | ihosy
# Processing Record 10 of Set 69 | la crosse
# Processing Record 11 of Set 69 | monroe
# Processing Record 12 of Set 69 | maltahohe
# Processing Record 13 of Set 69 | astoria
# Processing Record 14 of Set 69 | ushirombo
# Processing Record 15 of Set 69 | beckley
# Processing Record 16 of Set 69 | guapi
# Processing Record 17 of Set 69 | malinovoye ozero
# Processing Record 18 of Set 69 | san juan bautista
# Processing Record 19 of Set 69 | kununurra
# Processing Record 20 of Set 69 | bijbiara
# Processing Record 21 of Set 69 | kurayoshi
# Processing Record 22 of Set 69 | maykor
# Processing Record 23 of Set 69 | najran
# Processing Record 24 of Set 69 | sabang
# Processing Record 25 of Set 69 | thai binh
# Processing Record 26 of Set 69 | kapoeta
# Processing Record 27 of Set 69 | constitucion
# Processing Record 28 of Set 69 | vila franca do campo
# Processing Record 29 of Set 69 | romitan
# Processing Record 30 of Set 69 | pallasovka
# Processing Record 31 of Set 69 | assiniboia
# Processing Record 32 of Set 69 | nikel
# Processing Record 33 of Set 69 | vestmannaeyjar
# Processing Record 34 of Set 69 | ongandjera
# Processing Record 35 of Set 69 | sembe
# Processing Record 36 of Set 69 | byron bay
# Processing Record 37 of Set 69 | minnedosa
# Processing Record 38 of Set 69 | ulladulla
# Processing Record 39 of Set 69 | villa nueva
# Processing Record 40 of Set 69 | plasnica
# Processing Record 41 of Set 69 | marrakesh
# Processing Record 42 of Set 69 | mongo
# Processing Record 43 of Set 69 | anamur
# Processing Record 44 of Set 69 | hazorasp
# Processing Record 45 of Set 69 | kytmanovo
# Processing Record 46 of Set 69 | zachagansk
# City not found. Skipping...
# Processing Record 47 of Set 69 | belmonte
# Processing Record 48 of Set 69 | karacabey
# Processing Record 49 of Set 69 | aswan
# Processing Record 50 of Set 69 | damietta
# Processing Record 1 of Set 70 | korla
# Processing Record 2 of Set 70 | hirara
# Processing Record 3 of Set 70 | sancti spiritus
# Processing Record 4 of Set 70 | zhongshu
# Processing Record 5 of Set 70 | omboue
# Processing Record 6 of Set 70 | foumban
# Processing Record 7 of Set 70 | ostersund
# Processing Record 8 of Set 70 | berdigestyakh
# Processing Record 9 of Set 70 | dien bien
# City not found. Skipping...
# Processing Record 10 of Set 70 | kuala terengganu
# Processing Record 11 of Set 70 | selikhino
# Processing Record 12 of Set 70 | bemidji
# Processing Record 13 of Set 70 | camacha
# Processing Record 14 of Set 70 | kostomuksha
# Processing Record 15 of Set 70 | kamenskoye
# City not found. Skipping...
# Processing Record 16 of Set 70 | pemangkat
# Processing Record 17 of Set 70 | cienfuegos
# Processing Record 18 of Set 70 | boguchany
# Processing Record 19 of Set 70 | ewa beach
# Processing Record 20 of Set 70 | nadvoitsy
# Processing Record 21 of Set 70 | suleja
# Processing Record 22 of Set 70 | ayan
# Processing Record 23 of Set 70 | yeppoon
# Processing Record 24 of Set 70 | vanino
# Processing Record 25 of Set 70 | elat
# Processing Record 26 of Set 70 | coquimbo
# Processing Record 27 of Set 70 | prado
# Processing Record 28 of Set 70 | zeya
# Processing Record 29 of Set 70 | kalininsk
# Processing Record 30 of Set 70 | victor harbor
# Processing Record 31 of Set 70 | nioro
# Processing Record 32 of Set 70 | santa elena
# Processing Record 33 of Set 70 | itoman
# Processing Record 34 of Set 70 | roberto payan
# City not found. Skipping...
# Processing Record 35 of Set 70 | dewas
# Processing Record 36 of Set 70 | kraste
# City not found. Skipping...
# Processing Record 37 of Set 70 | atka
# City not found. Skipping...
# Processing Record 38 of Set 70 | yulara
# Processing Record 39 of Set 70 | odweyne
# Processing Record 40 of Set 70 | tahta
# Processing Record 41 of Set 70 | burica
# City not found. Skipping...
# Processing Record 42 of Set 70 | tra vinh
# Processing Record 43 of Set 70 | tinaquillo
# Processing Record 44 of Set 70 | cootamundra
# Processing Record 45 of Set 70 | vrangel
# Processing Record 46 of Set 70 | lomas de sargentillo
# Processing Record 47 of Set 70 | patos
# Processing Record 48 of Set 70 | kalmar
# Processing Record 49 of Set 70 | doka
# Processing Record 50 of Set 70 | tocopilla
# Processing Record 1 of Set 71 | madimba
# Processing Record 2 of Set 71 | grand gaube
# Processing Record 3 of Set 71 | save
# Processing Record 4 of Set 71 | shingu
# Processing Record 5 of Set 71 | saint-remy-de-provence
# Processing Record 6 of Set 71 | wajid
# Processing Record 7 of Set 71 | cabedelo
# Processing Record 8 of Set 71 | plouzane
# Processing Record 9 of Set 71 | khash
# Processing Record 10 of Set 71 | sao jose da coroa grande
# Processing Record 11 of Set 71 | piterka
# Processing Record 12 of Set 71 | walvis bay
# Processing Record 13 of Set 71 | tura
# Processing Record 14 of Set 71 | luanda
# Processing Record 15 of Set 71 | tateyama
# Processing Record 16 of Set 71 | vinh yen
# Processing Record 17 of Set 71 | ventspils
# Processing Record 18 of Set 71 | canoinhas
# Processing Record 19 of Set 71 | kousseri
# Processing Record 20 of Set 71 | mujiayingzi
# Processing Record 21 of Set 71 | chitungwiza
# Processing Record 22 of Set 71 | russi
# Processing Record 23 of Set 71 | rundu
# Processing Record 24 of Set 71 | sitka
# Processing Record 25 of Set 71 | tazmalt
# Processing Record 26 of Set 71 | bubaque
# Processing Record 27 of Set 71 | mansa
# Processing Record 28 of Set 71 | vostok
# Processing Record 29 of Set 71 | akdepe
# Processing Record 30 of Set 71 | hobyo
# Processing Record 31 of Set 71 | palmer
# Processing Record 32 of Set 71 | semnan
# Processing Record 33 of Set 71 | kloulklubed
# Processing Record 34 of Set 71 | tual
# Processing Record 35 of Set 71 | nacala
# Processing Record 36 of Set 71 | kilembe
# Processing Record 37 of Set 71 | balkanabat
# Processing Record 38 of Set 71 | horta
# Processing Record 39 of Set 71 | tautira
# Processing Record 40 of Set 71 | urumqi
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   Yellowknife  62.4560 -114.3525    -43.01        66           1
# 1  Longyearbyen  78.2186   15.6401     23.00        74          75
# 2     Upernavik  72.7868  -56.1549     19.96        80         100
# 3      Havelock  34.8791  -76.9013     50.00        57          75
# 4      Manthani  18.6500   79.6667     70.09        34           0
# 5  Beringovskiy  63.0500  179.3167     -8.25        88           1
# 6     Jamestown  42.0970  -79.2353     19.40        53           1
# 7        Castro -24.7911  -50.0119     76.44        48           0
# 8       Husavik  66.0449  -17.3389     32.00        64          75
# 9    Nikolskoye  59.7035   30.7861     10.40        79          75
#
#    Wind Speed Current Description Country                 Date
# 0        3.44                mist      CA  2021-02-06 17:47:44
# 1        3.44       broken clouds      SJ  2021-02-06 17:51:47
# 2        4.99     overcast clouds      GL  2021-02-06 17:51:47
# 3        8.05       broken clouds      US  2021-02-06 17:51:17
# 4        2.10           clear sky      IN  2021-02-06 17:51:47
# 5        8.43           clear sky      RU  2021-02-06 17:49:30
# 6       17.27           clear sky      US  2021-02-06 17:49:11
# 7        6.96           clear sky      BR  2021-02-06 17:51:48
# 8        4.61       broken clouds      IS  2021-02-06 17:51:48
# 9       17.90                snow      RU  2021-02-06 17:51:48

# %%
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description" ]

city_data_df = city_data_df[new_column_order]

city_data_df
# Out:
#               City Country                 Date      Lat       Lng  Max Temp  \
# 0      Yellowknife      CA  2021-02-06 17:47:44  62.4560 -114.3525    -43.01
# 1     Longyearbyen      SJ  2021-02-06 17:51:47  78.2186   15.6401     23.00
# 2        Upernavik      GL  2021-02-06 17:51:47  72.7868  -56.1549     19.96
# 3         Havelock      US  2021-02-06 17:51:17  34.8791  -76.9013     50.00
# 4         Manthani      IN  2021-02-06 17:51:47  18.6500   79.6667     70.09
# ...            ...     ...                  ...      ...       ...       ...
# 3420       Kilembe      UG  2021-02-06 18:09:44   0.2000   30.0000     67.26
# 3421    Balkanabat      TM  2021-02-06 18:09:44  39.5108   54.3671     50.34
# 3422         Horta      PT  2021-02-06 18:09:44  38.5333  -28.6333     60.80
# 3423       Tautira      PF  2021-02-06 18:07:29 -17.7333 -149.1500     73.40
# 3424        Urumqi      CN  2021-02-06 18:09:44  43.8010   87.6005      8.60
#
#       Humidity  Cloudiness  Wind Speed Current Description
# 0           66           1        3.44                mist
# 1           74          75        3.44       broken clouds
# 2           80         100        4.99     overcast clouds
# 3           57          75        8.05       broken clouds
# 4           34           0        2.10           clear sky
# ...        ...         ...         ...                 ...
# 3420        50          41        5.97    scattered clouds
# 3421        69          97        3.47     overcast clouds
# 3422        88          75       21.85       broken clouds
# 3423        88          75       13.80       moderate rain
# 3424        92          38        2.24                mist
#
# [3425 rows x 10 columns]

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
